# %%
import pandas as pd

# %%
energy = pd.read_csv("energydata_complete.csv")

# %%
energy.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
energy.dtypes
# Out:
# date            object
# Appliances       int64
# lights           int64
# T1             float64
# RH_1           float64
# T2             float64
# RH_2           float64
# T3             float64
# RH_3           float64
# T4             float64
# RH_4           float64
# T5             float64
# RH_5           float64
# T6             float64
# RH_6           float64
# T7             float64
# RH_7           float64
# T8             float64
# RH_8           float64
# T9             float64
# RH_9           float64
# T_out          float64
# Press_mm_hg    float64
# RH_out         float64
# Windspeed      float64
# Visibility     float64
# Tdewpoint      float64
# rv1            float64
# rv2            float64
# dtype: object

# %%
energy.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4    ...             T9   RH_9     T_out  \
# 0  19.79  44.730000  19.000000    ...      17.033333  45.53  6.600000
# 1  19.79  44.790000  19.000000    ...      17.066667  45.56  6.483333
# 2  19.79  44.933333  18.926667    ...      17.000000  45.50  6.366667
# 3  19.79  45.000000  18.890000    ...      17.000000  45.40  6.250000
# 4  19.79  45.000000  18.890000    ...      17.000000  45.40  6.133333
#
# ...

# %% [markdown]
# # Observations:
# 1. We have a date feature with Object type, which won't be suitable for the analysis.
# 2. So, we will change the data type for that feature to datetime.
# 3. Also, rest all other features are numeric.
# 4. Thus are dataset is numeric and don't have any categorical features.

# %%
energy['date'] = pd.to_datetime(energy['date'])

# %%
# Dataset characteristics
print("Number of instances in dataset = {}".format(energy.shape[0]))
print("Total number of columns = {}".format(energy.columns.shape[0]))
print("Column wise count of null values:-")
print(energy.isnull().sum())
# Out:
# Number of instances in dataset = 19735
# Total number of columns = 29
# Column wise count of null values:-
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %% [markdown]
# Variable Description
# ====================
#
# date time year-month-day hour:minute:second
#
# Appliances, energy use in Wh
#
# lights, energy use of light fixtures in the house in Wh
#
# T1, Temperature in kitchen area, in Celsius
#
# RH_1, Humidity in kitchen area, in %
#
# T2, Temperature in living room area, in Celsius
#
# RH_2, Humidity in living room area, in %
#
# T3, Temperature in laundry room area
#
# RH_3, Humidity in laundry room area, in %
#
# T4, Temperature in office room, in Celsius
#
# RH_4, Humidity in office room, in %
#
# T5, Temperature in bathroom, in Celsius
#
# RH_5, Humidity in bathroom, in %
#
# T6, Temperature outside the building (north side), in Celsius
#
# RH_6, Humidity outside the building (north side), in %
#
# T7, Temperature in ironing room , in Celsius
#
# RH_7, Humidity in ironing room, in %
#
# T8, Temperature in teenager room 2, in Celsius
#
# RH_8, Humidity in teenager room 2, in %
#
# T9, Temperature in parents room, in Celsius
#
# RH_9, Humidity in parents room, in %
#
# To, Temperature outside (from Chièvres weather station), in Celsius
#
# Pressure (from Chièvres weather station), in mm Hg
#
# RH_out, Humidity outside (from Chièvres weather station), in %
#
# Windspeed (from Chièvres weather station), in m/s
#
# Visibility (from Chièvres weather station), in km
#
# Tdewpoint (from Chièvres weather station), °C
#
# rv1, Random variable 1, nondimensional
#
# rv2, Rnadom variable 2, nondimensional
#
# Where indicated, data from the nearest airport weather station (Chièvres Airport, Belgium) was downloaded from a public data set from Reliable Prognosis, rp5.ru. Permission was obtained from Reliable Prognosis for the distribution of the 4 months of data.

# %% [markdown]
# # Observations:
# 1. We have a time series based data for a Energy consumption of a house.
# 2. Also, we have numeric dataset, as none of the feature is categorical.
# 3. We have given the  Appliances energy utilization reading for the 10 min interval with the temperature, humidity, visibility and windspeed reading for that instance.
# 4. We have total of 19735 records with all data available for each of the columns.

# %% [markdown]
# # Will analyse the Similar Variables.

# %%
# Columns for temperature sensors
temp_cols = ["T1", "T2", "T3", "T4", "T5", "T6", "T7", "T8", "T9", "T_out", "Tdewpoint"]

# Columns for humidity sensors
rho_cols = ["RH_1", "RH_2", "RH_3", "RH_4", "RH_5", "RH_6", "RH_7", "RH_8", "RH_9", "RH_out"]

# Columns for weather data
weather_cols = ["T_out", "Tdewpoint", "RH_out","Press_mm_hg", "Windspeed", "Visibility"]

# Target variable column
target = ["Appliances", "lights"]

# %%
energy[temp_cols].describe()
# Out:
#                  T1            T2            T3            T4            T5  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      21.686571     20.341219     22.267611     20.855335     19.592106
# std        1.606066      2.192974      2.006111      2.042884      1.844623
# min       16.790000     16.100000     17.200000     15.100000     15.330000
# 25%       20.760000     18.790000     20.790000     19.530000     18.277500
# 50%       21.600000     20.000000     22.100000     20.666667     19.390000
# 75%       22.600000     21.500000     23.290000     22.100000     20.619643
# max       26.260000     29.856667     29.236000     26.200000     25.795000
#
#                  T6            T7            T8            T9         T_out  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean       7.910939     20.267106     22.029107     19.485828      7.411665
# ...

# %%
energy[temp_cols].corr().abs()
# Out:
#                  T1        T2        T3        T4        T5        T6  \
# T1         1.000000  0.836834  0.892402  0.877001  0.885247  0.654769
# T2         0.836834  1.000000  0.735245  0.762066  0.720550  0.801186
# T3         0.892402  0.735245  1.000000  0.852778  0.888169  0.686882
# T4         0.877001  0.762066  0.852778  1.000000  0.871813  0.652350
# T5         0.885247  0.720550  0.888169  0.871813  1.000000  0.629161
# T6         0.654769  0.801186  0.686882  0.652350  0.629161  1.000000
# T7         0.838705  0.663660  0.847374  0.877763  0.870624  0.619085
# T8         0.825413  0.578191  0.795283  0.796256  0.824981  0.482836
# T9         0.844777  0.675535  0.901324  0.889439  0.911055  0.667177
# T_out      0.682846  0.792255  0.699417  0.663478  0.651321  0.974787
# Tdewpoint  0.571309  0.582602  0.645886  0.519471  0.588362  0.764242
#
#                  T7        T8        T9     T_out  Tdewpoint
# T1         0.838705  0.825413  0.844777  0.682846   0.571309
# ...

# %% [markdown]
# # Observations:
# 1. The temperature range for alomst all recorded reading is between 14.89 to 29.86 degree Celcius.
# 2. However the temperature range for T6, Tdewpoint and T_out is -6.6 to 28.9 degree Celcius, which may be due the fact that the T6 and T_out are the readings taken from the outside of the building.
# 3. All the temperatures are very well correlated with each other.

# %%
energy[rho_cols].describe()
# Out:
#                RH_1          RH_2          RH_3          RH_4          RH_5  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.259739     40.420420     39.242500     39.026904     50.949283
# std        3.979299      4.069813      3.254576      4.341321      9.022034
# min       27.023333     20.463333     28.766667     27.660000     29.815000
# 25%       37.333333     37.900000     36.900000     35.530000     45.400000
# 50%       39.656667     40.500000     38.530000     38.400000     49.090000
# 75%       43.066667     43.260000     41.760000     42.156667     53.663333
# max       63.360000     56.026667     50.163333     51.090000     96.321667
#
#                RH_6          RH_7          RH_8          RH_9        RH_out
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      54.609083     35.388200     42.936165     41.552401     79.750418
# ...

# %%
energy[rho_cols].corr().abs()
# Out:
#             RH_1      RH_2      RH_3      RH_4      RH_5      RH_6      RH_7  \
# RH_1    1.000000  0.797535  0.844677  0.880359  0.303258  0.245126  0.801122
# RH_2    0.797535  1.000000  0.678326  0.721435  0.250271  0.389933  0.690584
# RH_3    0.844677  0.678326  1.000000  0.898978  0.375422  0.514912  0.832685
# RH_4    0.880359  0.721435  0.898978  1.000000  0.352591  0.392178  0.894301
# RH_5    0.303258  0.250271  0.375422  0.352591  1.000000  0.263797  0.325808
# RH_6    0.245126  0.389933  0.514912  0.392178  0.263797  1.000000  0.357222
# RH_7    0.801122  0.690584  0.832685  0.894301  0.325808  0.357222  1.000000
# RH_8    0.736196  0.679777  0.828822  0.847259  0.359840  0.489580  0.883984
# RH_9    0.764001  0.676467  0.833538  0.856591  0.272197  0.391943  0.858686
# RH_out  0.274126  0.584911  0.356192  0.336813  0.185941  0.718587  0.378519
#
#             RH_8      RH_9    RH_out
# RH_1    0.736196  0.764001  0.274126
# RH_2    0.679777  0.676467  0.584911
# ...

# %% [markdown]
# # Observations:
# 1. We have almost all humidity features which are ranging from 20.46% to 63.36%.
# 2. However for the RH_5 & RH_out and RH_6 we have range of 24% to 100% and 1% to 99.9%, respectively.
# 3. This is due to the fact that RH_5 is the humidity recorded at the bathroom and RH_6 & RH_out are the humidities recorded at outside the building.
# 4. Thus the correlation of the humidity features RH_1, RH_2, RH_3, RH_4, RH_7, RH_8, RH_9 has significant correlation with each other and very less correlation to other humidity features.

# %%
energy[weather_cols].describe()
# Out:
#               T_out     Tdewpoint        RH_out   Press_mm_hg     Windspeed  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean       7.411665      3.760707     79.750418    755.522602      4.039752
# std        5.317409      4.194648     14.901088      7.399441      2.451221
# min       -5.000000     -6.600000     24.000000    729.300000      0.000000
# 25%        3.666667      0.900000     70.333333    750.933333      2.000000
# 50%        6.916667      3.433333     83.666667    756.100000      3.666667
# 75%       10.408333      6.566667     91.666667    760.933333      5.500000
# max       26.100000     15.500000    100.000000    772.300000     14.000000
#
#          Visibility
# count  19735.000000
# mean      38.330834
# std       11.794719
# min        1.000000
# 25%       29.000000
# 50%       40.000000
# 75%       40.000000
# max       66.000000

# %%
energy[weather_cols].corr().abs()
# Out:
#                 T_out  Tdewpoint    RH_out  Press_mm_hg  Windspeed  Visibility
# T_out        1.000000   0.790661  0.574197     0.143249   0.192936    0.077367
# Tdewpoint    0.790661   1.000000  0.036506     0.244098   0.125972    0.042190
# RH_out       0.574197   0.036506  1.000000     0.092017   0.176458    0.083125
# Press_mm_hg  0.143249   0.244098  0.092017     1.000000   0.235032    0.040315
# Windspeed    0.192936   0.125972  0.176458     0.235032   1.000000    0.007516
# Visibility   0.077367   0.042190  0.083125     0.040315   0.007516    1.000000

# %% [markdown]
# # Observations:
# 1. We have pressure data ranges from 729.3 mmHg to 772.30 mmHg
# 2. We have Windspeed recorded ranges from 0 to 14 m/s
# 3. Also, the visbility recorded was ranges from 1 to 66 kms.
# 4. This features have very low correlation factors among each other.

# %%
energy[["rv1","rv2"]].describe()
# Out:
#                 rv1           rv2
# count  19735.000000  19735.000000
# mean      24.988033     24.988033
# std       14.496634     14.496634
# min        0.005322      0.005322
# 25%       12.497889     12.497889
# 50%       24.897653     24.897653
# 75%       37.583769     37.583769
# max       49.996530     49.996530

# %%
energy[["rv1","rv2"]].corr().abs()
# Out:
#      rv1  rv2
# rv1  1.0  1.0
# rv2  1.0  1.0

# %%
(energy['rv1']-energy['rv2']==0).count() - energy.shape[0]
# Out:
# 0

# %% [markdown]
# # Observations:
# 1. We have rv1 and rv2, 2 random variable which was just added to check validate the performance of the feature selections models.
# 2. We found the perfect correlation between these two variables.
# 3. Also, it is proved that the both columns are identical, giving redundancy in the dataset.

# %%
energy[target].describe()
# Out:
#          Appliances        lights
# count  19735.000000  19735.000000
# mean      97.694958      3.801875
# std      102.524891      7.935988
# min       10.000000      0.000000
# 25%       50.000000      0.000000
# 50%       60.000000      0.000000
# 75%      100.000000      0.000000
# max     1080.000000     70.000000

# %%
energy[target].corr().abs()
# Out:
#             Appliances    lights
# Appliances    1.000000  0.197278
# lights        0.197278  1.000000

# %%
import matplotlib.pyplot as plt

# %%
# Histogram for appliances

plt.xlabel("Appliance Energy Consumption in Wh", fontsize="x-large")
plt.ylabel("Frequency", fontsize="x-large")

energy["Appliances"].hist(figsize=(16, 8), bins=100)

# %%
print("Percentage of dataset in range of 0-200 Wh")
print("{:.3f}%".format(
    (energy[energy.Appliances <= 200]["Appliances"].count()*100.0) / energy.shape[0]
))
# Out:
# Percentage of dataset in range of 0-200 Wh
# 90.291%

# %%
# Histogram for appliances

plt.xlabel("Appliance Energy Consumption in Wh", fontsize="x-large")
plt.ylabel("Frequency", fontsize="x-large")

energy["lights"].hist(figsize=(16, 8), bins=50)

# %%
energy.groupby("lights").count()["date"]
# Out:
# lights
# 0     15252
# 10     2212
# 20     1624
# 30      559
# 40       77
# 50        9
# 60        1
# 70        1
# Name: date, dtype: int64

# %%
print("Percentage of dataset with lights off")
print("{:.3f}%".format(
    (energy[energy.lights < 10]["lights"].count()*100.0) / energy.shape[0]
))
# Out:
# Percentage of dataset with lights off
# 77.284%

# %% [markdown]
# # Observations:
# 1. We can see that Maximum appliance consumption is 1080 Wh.
# 2. However, we have 90.21% of data for which the appliance energy consumption is less than 200 Wh.
# 3. Similarly, the maximum lights consumption is 70 Wh.
# 4. But 77.28% of data shows that the lights were off.
# 5. This observations show that there are less number of cases when the appliance energy consumption were high.

# %%
# %matplotlib inline
histograms = energy.hist(figsize=(16, 16), bins=20)

# %% [markdown]
# # Observations:
# 1. All temperature features follows normal distribution, but T9 and T7.
# 2. Similarly, almost all humidity features follow normal distribution except RH_6 and RH_out.
# 3. From the distribution plot, fetures visibility, windspeed, lights and appliances are skewed.
# 4. Also, no features follows the similar distribution as appliances.

# %% [markdown]
# # Let's now check for the high correlation combinations within our energy dataset.

# %%
energy.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
corr_temp = energy[['Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
       'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
       'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
       'Visibility', 'Tdewpoint', 'rv1', 'rv2']]

# %%
# To generate all pairs for given columns
from itertools import combinations

for pair in combinations(corr_temp.columns, 2):
    col_1, col_2 = pair
    # Calculate the coefficient and p-value
    corr_coef, p_val = pearsonr(corr_temp[col_1], corr_temp[col_2])
    # Check for high correlation
    if abs(corr_coef) > 0.88:
        # Print details for pairs with high correlation
        print("Column pair : {}, {}".format(*pair))
        print("Correlation coefficient : {}".format(corr_coef))
        #print("p-value : {}".format(p_val))
# Out:
# Column pair : T1, T3
# Correlation coefficient : 0.8924022851105653
# Column pair : T1, T5
# Correlation coefficient : 0.8852468734266528
# Column pair : RH_1, RH_4
# Correlation coefficient : 0.8803585351891954
# Column pair : T3, T5
# Correlation coefficient : 0.8881689127749807
# Column pair : T3, T9
# Correlation coefficient : 0.901323585082566
# Column pair : RH_3, RH_4
# Correlation coefficient : 0.8989782902830767
# Column pair : T4, T9
# Correlation coefficient : 0.8894391511402545
# Column pair : RH_4, RH_7
# Correlation coefficient : 0.8943012488817835
# Column pair : T5, T9
# Correlation coefficient : 0.9110551178067928
# Column pair : T6, T_out
# Correlation coefficient : 0.9747866900664536
# Column pair : T7, T8
# Correlation coefficient : 0.8821232262844055
# Column pair : T7, T9
# Correlation coefficient : 0.9447764235687443
# Column pair : RH_7, RH_8
# Correlation coefficient : 0.8839839643177076
# Column pair : rv1, rv2
# Correlation coefficient : 1.0

# %% [markdown]
# # Observations:
# 1. rv1 and rv2 shows perfect correlation. And as derived in above observations, rv2 is redundant feature.
# 2. Feature T9 shows high correlation with T3, T4, T5, T7.
# 3. Thus T9 can be consider as a overhead in the dataset.
# 4. Similarly, T5 has a high correlation with the T9, T3 and T1 which thus acts added redundancy.
# 5. Also, we know T6 and T_out are exterior temperatue features, and shows high degree of correlations.
# 6. We can get rid of either of the above two fetures to lower the data redundancy.

# %% [markdown]
# # Let's get in to deep!
# 1. As we have time series data, we can drill down our observation for time specific analysis for the appliance energy consumption.
# 2. For that we need to add some new features which will help us to get more insight.

# %%
# To get the month for that record
energy['month'] = energy['date'].dt.month

# To get the specific time for that record
energy['time'] = energy['date'].dt.time

#---------------------------------------------------
p = []
q = []
for i in energy['date']:
    p.append(i.strftime("%j"))
    q.append(i.hour * 60 + i.minute)
#---------------------------------------------------

# To get the Day of the year for that record
energy['DOY'] = pd.DataFrame({'DOY': p})

# To get the minutes from midnight for that record
energy['MNM'] = pd.DataFrame({'MNM': q})

# To get the only date 
energy['Only_Date'] = energy['date'].dt.date

# To get the weekday for that record
energy['Day of Week'] = energy['date'].dt.weekday

# %%
energy.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2', 'month', 'time', 'DOY', 'MNM',
#        'Only_Date', 'Day of Week'],
#       dtype='object')

# %%
energy.head()
# Out:
#                  date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0 2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1 2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2 2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3 2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4 2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4     ...       Visibility  Tdewpoint        rv1  \
# 0  19.79  44.730000  19.000000     ...        63.000000        5.3  13.275433
# 1  19.79  44.790000  19.000000     ...        59.166667        5.2  18.606195
# 2  19.79  44.933333  18.926667     ...        55.333333        5.1  28.642668
# 3  19.79  45.000000  18.890000     ...        51.500000        5.0  45.410389
# 4  19.79  45.000000  18.890000     ...        47.666667        4.9  10.084097
#
# ...

# %% [markdown]
# # Observations:
# 1. By looking at the data we need to plot the graphs for appliances energy consumption
#    over period of time and with respect to other features for the analysis.
# 2. To get this graph visually effective we will try to scale each feature to fit into the graph.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
energy.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2', 'month', 'time', 'DOY', 'MNM',
#        'Only_Date', 'Day of Week'],
#       dtype='object')

# %% [markdown]
# # Warning:
# 1. We can scale the numerical features only.
# 2. Hence we need to consider all the columns from the df except date and time.

# %%
energy_scaler = pd.DataFrame(energy[['Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
       'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
       'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
       'Visibility', 'Tdewpoint', 'rv1', 'rv2', 'month','DOY', 'MNM','Day of Week']])

# %%
scaler.fit(energy_scaler)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
energy_scaler = scaler.transform(energy_scaler)

# %%
energy_scaler = pd.DataFrame(energy_scaler)

# %%
energy_scaler.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.367676  3.301264 -1.118645  1.843821 -0.520411  1.073683 -1.235063
# 1 -0.367676  3.301264 -1.118645  1.616807 -0.520411  1.057097 -1.235063
# 2 -0.465215  3.301264 -1.118645  1.517959 -0.520411  1.033550 -1.235063
# 3 -0.465215  4.561378 -1.118645  1.459321 -0.520411  1.024540 -1.235063
# 4 -0.367676  4.561378 -1.118645  1.526336 -0.520411  1.009797 -1.235063
#
#          7         8         9     ...          22        23        24  \
# 0  1.686130 -0.908217  1.506438    ...     0.82208  1.207694  2.091596
# 1  1.704566 -0.908217  1.604528    ...     0.82208  1.071703  1.766584
# 2  1.748608 -0.944115  1.580918    ...     0.82208  0.935713  1.441572
# 3  1.769092 -0.962063  1.542526    ...     0.82208  0.799723  1.116559
# 4  1.769092 -0.962063  1.497991    ...     0.82208  0.663733  0.791547
#
#          25        26        27        28        29        30        31
# ...

# %%
energy_scaler = energy_scaler.rename(columns={0:'Appliances', 1:'lights', 2:'T1', 3:'RH_1', 4:'T2', 5:'RH_2', 6:'T3',
       7:'RH_3', 8:'T4', 9:'RH_4', 10:'T5', 11:'RH_5', 12:'T6', 13:'RH_6', 14:'T7', 15:'RH_7', 16:'T8',
       17:'RH_8', 18:'T9', 19:'RH_9', 20:'T_out', 21:'Press_mm_hg', 22:'RH_out', 23:'Windspeed',
       24:'Visibility', 25:'Tdewpoint', 26:'rv1', 27:'rv2', 28:'month',29:'DOY', 30:'MNM',31:'Day of Week'})

# %%
energy_scaler['time'] = energy['time']
energy_scaler['date'] = energy['date']
energy_scaler['Only_Date'] = energy['Only_Date']

# %%
energy_scaler.head()
# Out:
#    Appliances    lights        T1      RH_1        T2      RH_2        T3  \
# 0   -0.367676  3.301264 -1.118645  1.843821 -0.520411  1.073683 -1.235063
# 1   -0.367676  3.301264 -1.118645  1.616807 -0.520411  1.057097 -1.235063
# 2   -0.465215  3.301264 -1.118645  1.517959 -0.520411  1.033550 -1.235063
# 3   -0.465215  4.561378 -1.118645  1.459321 -0.520411  1.024540 -1.235063
# 4   -0.367676  4.561378 -1.118645  1.526336 -0.520411  1.009797 -1.235063
#
#        RH_3        T4      RH_4     ...      Tdewpoint       rv1       rv2  \
# 0  1.686130 -0.908217  1.506438     ...       0.366975 -0.807974 -0.807974
# 1  1.704566 -0.908217  1.604528     ...       0.343135 -0.440240 -0.440240
# 2  1.748608 -0.944115  1.580918     ...       0.319294  0.252109  0.252109
# 3  1.769092 -0.962063  1.542526     ...       0.295454  1.408801  1.408801
# 4  1.769092 -0.962063  1.497991     ...       0.271613 -1.028122 -1.028122
#
# ...

# %%
fig, ax = plt.subplots(figsize=(15,7))
energy.plot
energy.groupby(['month']).mean()['Appliances'].plot(ax=ax, legend= True)

# %%
import numpy as np

# %%
fig, ax = plt.subplots(figsize=(15,7))
energy.groupby(['month']).mean()[['Appliances','lights']].plot(ax=ax,kind='bar')
plt.xticks(np.arange(5), ('Jan', 'Feb', 'Mar', 'Apr', 'May'),rotation=0)
# Out:
# ([<matplotlib.axis.XTick at 0x2323b4a3d68>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
fig, ax = plt.subplots(figsize=(15,7))
energy.plot
energy.groupby(['month']).mean()['lights'].plot(ax=ax, legend= True)

# %% [markdown]
# # Observations:
# 1. From the month January to February the appliance energy consumption increases and then decreases in the month of March.
# 2. Again the rise in the appliance energy increase in April and further drop in the month of May.
# 3. Similarly, there was a rise in the light usage for the month February and then gradual decrease in March, April and May.

# %% [markdown]
# # Let's plot the graph for the appliances energy utilization with respect to the light usage.

# %%
# Energy consumption during the 24 Hr time period
fig, ax = plt.subplots(figsize=(15,7))
energy.groupby(['time']).mean()['lights'].plot(ax=ax,label='Consumption By Light')
energy[energy['lights']==0].groupby(['time']).mean()['Appliances'].plot(ax=ax,label='Appliances Consumption- Lights OFF',color='green')
energy[energy['lights']!=0].groupby(['time']).mean()['Appliances'].plot(ax=ax,label='Appliances Consumption- Lights ON',color='black')
ax.legend()

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import seaborn as sns

# %%
py.sign_in('pramodnagare1993', 'bbmknNZrUUGwuJgTxLTp')

energy_time = energy.groupby('time').mean().reset_index()['time']
# Create traces
trace0 = go.Scatter(
    x = energy_time,
    y = energy[energy['lights']==0].groupby(['time']).mean()['Appliances'],
    xaxis = 'Time',
    yaxis = 'Energy Consumped in Wh',
    mode = 'lines+markers',
    name = 'Average Appliance energy consumped| lights = OFF'
)
trace1 = go.Scatter(
    x = energy_time,
    y = energy[energy['lights']!=0].groupby(['time']).mean()['Appliances'],
    xaxis = 'Time',
    yaxis = 'Energy Consumped in Wh',
    mode = 'lines+markers',
    name = 'Average Appliance energy consumption in Wh| lights = ON'
)
trace2 = go.Scatter(
    x = energy_time,
    y = energy.groupby(['time']).mean()['lights'],
    xaxis = 'Time',
    yaxis = 'Energy Consumped in Wh',
    mode = 'lines+markers',
    name = 'Average Lights energy consumption in Wh'
)
layout = go.Layout(
    title='Average Applainaces energy consumption with light status',
    xaxis=dict(
        title='Time',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    ),
    yaxis=dict(
        title='Applaince energy consumption in Wh',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    )
)
data = [trace0, trace1, trace2]
py.iplot(data, filename='scatter-mode')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~pramodnagare1993/5.embed" height="525px" width="100%"></iframe>

# %%
# Appliances Energy consumption during the 24 Hr time period
fig, ax = plt.subplots(figsize=(15,7))
energy.groupby(['time']).mean()['Appliances'].plot(ax=ax,label='Mean Appliances Consumption',color='green')
ax.legend()

# %%
sns.jointplot(x='Appliances', y='lights', data = energy, kind='scatter')

# %% [markdown]
# # Observations:
# 1. (Average) Appliance energy utilizations is low when lights are OFF.
# 2. (Average) Appliance energy utilizations is high when lights are ON.
# 3. Also, Appliance energy utilizations follows a trand with respect to time.
# 4. For the night time (00:00:00 to 06:00:00) the energy consumption is lowest.
# 5. From the time 06:00:00 energy consumption started rising, and got steady till time 17:20:00
# 6. Then the peak hours started till 19:00:00
# 8. After that, the energy utilization started decreasing.

# %%
fig, ax = plt.subplots(figsize=(15,7))
energy[(energy['Day of Week']==5)|(energy['Day of Week']==6)].groupby(['time']).mean()['Appliances'].plot(ax=ax, label='Weekend')
energy[(energy['Day of Week']!=5)&(energy['Day of Week']!=6)].groupby(['time']).mean()['Appliances'].plot(ax=ax,label = 'Weekday')
ax.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# # Observations:
# 1. for normal hours 07:00:00 to 17:00:00 the energy utilization on weekend increases as compared to weekdays.
# 2. But for the peak hours ie. 17:00:00 to 19:00:00 the energy utilization decreases.

# %% [markdown]
# # Now we will plot the graphs for the Appliance energy consumption for the different temperatures

# %%
fig, ax = plt.subplots(figsize=(15,7))
energy_scaler.groupby(['time']).mean()[['T6','Windspeed','T2', 'T_out']].plot(ax=ax)
energy_scaler.groupby(['time']).mean()['Appliances'].plot(ax=ax)
ax.legend()

# %% [markdown]
# # Observations:
# 1. Features T6 and T_out seems to follow each other and with the appliances energy usage.
# 2. Also, the same goes with the windspeed and the other variables from the plot.

# %%
fig, ax = plt.subplots(figsize=(15,7))
energy_scaler.groupby(['time']).mean()[['T1','T2', 'T3', 'T4']].plot(ax=ax)
energy_scaler.groupby(['time']).mean()['Appliances'].plot(ax=ax)
ax.legend()

# %% [markdown]
# # Observations:
# 1. Featuers T1, T2, T3, T4 are the temperature belongs to the same floor but for different rooms.
# 1. From the above graph we can say that, Featuers T1, T2, T3, T4 Follows each other.
# 2. However, among all these features, T2 shows significant follow-up with the Appliances energy usage.

# %%
fig, ax = plt.subplots(figsize=(15,7))
energy_scaler.groupby(['time']).mean()[['T5','T6', 'T7', 'T8', 'T9']].plot(ax=ax)
energy_scaler.groupby(['time']).mean()['Appliances'].plot(ax=ax)
ax.legend()

# %% [markdown]
# # Observations:
# 1. Features T5, T6, T7, T8 and T9 are the temperature for the 2nd floor of the house.
# 2. Among all these features T6 shows the significant pattern for the Appliance energy utilization.

# %%
fig, ax = plt.subplots(figsize=(15,7))
energy_scaler.groupby(['time']).mean()[['RH_1','RH_2', 'RH_3', 'RH_4']].plot(ax=ax)
energy_scaler.groupby(['time']).mean()['Appliances'].plot(ax=ax)
ax.legend()

# %% [markdown]
# # Observations:
# 1. Plot shows the humidity for the different rooms on the 1st floor of the house.
# 2. All these fetures shows the significant pattern for the appliance energy consumption.

# %%
fig, ax = plt.subplots(figsize=(15,7))
energy_scaler.groupby(['time']).mean()[['RH_5','RH_6', 'RH_7', 'RH_8', 'RH_9']].plot(ax=ax)
energy_scaler.groupby(['time']).mean()['Appliances'].plot(ax=ax)
ax.legend()

# %% [markdown]
# # Observations:
# 1. The above plot shows the curve for the appliances energy utilization over time.
# 2. Among all these features RH_6, RH_7, RH_8 and RH_9 shows the great follow-up for the appliance energy utilization.

# %%
fig, ax = plt.subplots(figsize=(15,7))
energy_scaler.groupby(['time']).mean()[['Windspeed', 'Visibility', 'Tdewpoint']].plot(ax=ax)
energy_scaler.groupby(['time']).mean()['Appliances'].plot(ax=ax)
ax.legend()

# %% [markdown]
# # Observations:
# 1. Features windspeed and Tdewpoint shows some significant follow-up pattern with the Appliances energy consumption.
# 2. Whereas, visibility does not shows any useful information for the energy prediction.

# %%
fig, ax = plt.subplots(figsize=(15,7))
energy_scaler.groupby(['time']).mean()[['rv1']].plot(ax=ax)
energy_scaler.groupby(['time']).mean()['Appliances'].plot(ax=ax)
ax.legend()

# %% [markdown]
# # Observations:
# 1. Feature rv1 does not have any specific pattern in the Appliances energy consumption over time.
