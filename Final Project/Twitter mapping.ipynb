# %%
import tweepy
from tweepy import OAuthHandler
import json
 
consumer_key = '1Cvu0r3U1bafJE0prSuJXUhS6'
consumer_secret = 'l2NhimsNqLQbM490spvEt2sDHJs4KJEeWQ2FkHP2P0LpjggtjY'
access_token = '420232136-pNrWEakqUOq8kbHPsX2jCTrm7ocyAyIYpHe3mCNZ'
access_secret = 'wfzXzbtqYfhIhsD2egUJC8l7Gy2fMcrKrw2Pq50BW9qZA'


auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %%
for status in tweepy.Cursor(api.home_timeline, q="mark zuckerberg").items():
    # Process a single status
    print(status.text)
# Out:
# “Opportunity follows struggle,follows effort &amp; follows hard work. It doesn't come before.”So don’t miss any opportunity👍 #DailyInspiration
# You are one in a million my dear mother. Hyderabad will fill your heart with even more love. All the best mama ❤️ https://t.co/3B3DzhQWdU
# Thank you all so much for the kind wishes to Aishwarya and me on our anniversary. Lots of love right back at all of you. 🤗
# Thankyou outlookindia for the osmawards for the INSPIRATION of the year award . This is a real… https://t.co/HiJvgDM1oE
# Look-2 Ready for the #osm award😬styled by @mohitraich Outfit- nikitadmhaisalkar
# Bracelet -… https://t.co/yemJ6zx5j1
# Thank you!! https://t.co/h5GwMQFA9Q
# ❤️ https://t.co/cXBKAAoCMQ
# Ready for a Brand event in Delhi
# styled by @mohitraich
# Top - @dolcegabbana at @mytheresa_com… https://t.co/hrBL3HHzxx
# Thank you all for the sweet birthday wishes for Nysa. https://t.co/awffcSPv58
# Signup up on https://t.co/OL9WtDlRR6 &amp; get chance to meet me.
# Details: https://t.co/0f2VA97aeb
#
# Dimag Lagao,… https://t.co/oZkvGW2r6H
# And there is a GOD! 😬😬😬😬just landed in Delhi and got news ,our SIMBAAAAA is back home😬😬… https://t.co/9UdIpSne7U
# Watched #Beyondtheclouds A film with some moments that really stay with you and of course a wonderful debut by the… https://t.co/AUf4NL3fzW
# First 100 of #vivoipl2018 &amp; 2nd #Manofthematch 4 @henrygayle ThankGod🙏 I was on the right side of the #Gaylestorm… https://t.co/LHLmugXRaI
# One word that comes to mind...Imperial. Presenting the newly launched collection #LalQuilaByPCJ, now in stores!… https://t.co/RHocHhVUZp
# @juniorbachchan
# 🤣🤣🤣🤣🤣🤣🤣 #albumsthatshouldhavebeenmade https://t.co/M3dU2TeeQV
# @DeShobhaa
# @bhogleharsha
# @aliaa08 @RanveerOfficial
# @sardesairajdeep
# @Ram_Guha
# @RajkummarRao @ReallySwara @RichaChadha
# @SrBachchan
# @sachin_rt
# Come join us on 1st May.
# Love,
# a. https://t.co/H4CLHeC7SH
# Thankyou @Sachbang 🙏😔 https://t.co/4hG4Ex0R8N
# Vinyl Lovers, this is for you... https://t.co/Qvp1Qi4tjm
# Check this out ! https://t.co/RLPeBR85D9
# This is BIG NEWS😬Excited to announce my association with @mamaearthindia  as an equity investor.… https://t.co/Adn5I8HJUF
# Kya baat hain super hero!!!! @HarshKapoor_  this looks seriously kick ass. Can’t wait for the trailer.… https://t.co/PBrohnAg7z
# Core training my way through the summer heat with these wooden beads...great for the back and stomach muscles. Also… https://t.co/oXpmst8eBh

#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     195         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     196             # Reached end of current page, get the next page...
# --> 197             self.current_page = self.page_iterator.next()
#     198             self.page_index = -1
#     199         self.page_index += 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     106
#     107         if self.index >= len(self.results) - 1:
# --> 108             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     109
#     110             if hasattr(self.method, '__self__'):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     248             return method
#     249         else:
# --> 250             return method.execute()
#     251
#     252     # Set pagination mode
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     232                     raise RateLimitError(error_msg, resp)
#     233                 else:
# --> 234                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     235
#     236             # Parse the response payload
#
# TweepError: Twitter error response: status code = 429

# %%
def process_or_store(tweet):
    print(json.dumps(tweet))

# %%
for status in tweepy.Cursor(api.home_timeline).items(10):
    # Process a single status
    process_or_store(status._json)
# Out:
# {"created_at": "Thu Apr 19 16:58:48 +0000 2018", "id": 987012650201595906, "id_str": "987012650201595906", "text": "Thankyou @Sachbang \ud83d\ude4f\ud83d\ude14 https://t.co/4hG4Ex0R8N", "truncated": false, "entities": {"hashtags": [], "symbols": [], "user_mentions": [{"screen_name": "Sachbang", "name": "Sachin Bangera", "id": 29650784, "id_str": "29650784", "indices": [9, 18]}], "urls": [{"url": "https://t.co/4hG4Ex0R8N", "expanded_url": "https://twitter.com/sachbang/status/986863693379055616", "display_url": "twitter.com/sachbang/statu\u2026", "indices": [22, 45]}]}, "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 115341081, "id_str": "115341081", "name": "SHILPA SHETTY KUNDRA", "screen_name": "TheShilpaShetty", "location": "", "description": "Full time Mother &Wife ,Actor, entrepreneur, Yogi ,author of @greatindiandiet. Order my book https://t.co/WjHQHe2A7g\u2026", "url": "https://t.co/9SG3iOGst0", "entities": {"url": {"urls": [{"url": "https://t.co/9SG3iOGst0", "expanded_url": "http://theshilpashetty.com", "display_url": "theshilpashetty.com", "indices": [0, 23]}]}, "description": {"urls": [{"url": "https://t.co/WjHQHe2A7g", "expanded_url": "http://bit.ly/Domesticdivapr", "display_url": "bit.ly/Domesticdivapr", "indices": [93, 116]}]}}, "protected": false, "followers_count": 5693027, "friends_count": 138, "listed_count": 8626, "created_at": "Thu Feb 18 10:41:18 +0000 2010", "favourites_count": 64, "utc_offset": 19800, "time_zone": "Mumbai", "geo_enabled": true, "verified": true, "statuses_count": 5300, "lang": "en", "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "1A1B1F", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/407212316/ssk_ghb.jpg", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/407212316/ssk_ghb.jpg", "profile_background_tile": true, "profile_image_url": "http://pbs.twimg.com/profile_images/929324251458420736/bXcF9ywJ_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/929324251458420736/bXcF9ywJ_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/115341081/1516280215", "profile_link_color": "2FC2EF", "profile_sidebar_border_color": "181A1E", "profile_sidebar_fill_color": "252429", "profile_text_color": "666666", "profile_use_background_image": true, "has_extended_profile": true, "default_profile": false, "default_profile_image": false, "following": true, "follow_request_sent": false, "notifications": false, "translator_type": "none"}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": true, "quoted_status_id": 986863693379055616, "quoted_status_id_str": "986863693379055616", "quoted_status": {"created_at": "Thu Apr 19 07:06:54 +0000 2018", "id": 986863693379055616, "id_str": "986863693379055616", "text": "MUMBAI: Simba, a 2 year old cat, has gone missing from Juhu. If you\u2019ve seen him or know anything about him, pls con\u2026 https://t.co/m78iVujYZK", "truncated": true, "entities": {"hashtags": [], "symbols": [], "user_mentions": [], "urls": [{"url": "https://t.co/m78iVujYZK", "expanded_url": "https://twitter.com/i/web/status/986863693379055616", "display_url": "twitter.com/i/web/status/9\u2026", "indices": [117, 140]}]}, "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 29650784, "id_str": "29650784", "name": "Sachin Bangera", "screen_name": "Sachbang", "location": "Mumbai, India", "description": "Associate Director of Celebrity and Publi ...
# {"created_at": "Thu Apr 19 16:39:57 +0000 2018", "id": 987007908914188288, "id_str": "987007908914188288", "text": "Vinyl Lovers, this is for you... https://t.co/Qvp1Qi4tjm", "truncated": false, "entities": {"hashtags": [], "symbols": [], "user_mentions": [], "urls": [], "media": [{"id": 987007905974005760, "id_str": "987007905974005760", "indices": [33, 56], "media_url": "http://pbs.twimg.com/media/DbKOdgoVMAAPIE7.jpg", "media_url_https": "https://pbs.twimg.com/media/DbKOdgoVMAAPIE7.jpg", "url": "https://t.co/Qvp1Qi4tjm", "display_url": "pic.twitter.com/Qvp1Qi4tjm", "expanded_url": "https://twitter.com/arrahman/status/987007908914188288/photo/1", "type": "photo", "sizes": {"thumb": {"w": 150, "h": 150, "resize": "crop"}, "medium": {"w": 819, "h": 1200, "resize": "fit"}, "small": {"w": 464, "h": 680, "resize": "fit"}, "large": {"w": 1398, "h": 2048, "resize": "fit"}}}]}, "extended_entities": {"media": [{"id": 987007905974005760, "id_str": "987007905974005760", "indices": [33, 56], "media_url": "http://pbs.twimg.com/media/DbKOdgoVMAAPIE7.jpg", "media_url_https": "https://pbs.twimg.com/media/DbKOdgoVMAAPIE7.jpg", "url": "https://t.co/Qvp1Qi4tjm", "display_url": "pic.twitter.com/Qvp1Qi4tjm", "expanded_url": "https://twitter.com/arrahman/status/987007908914188288/photo/1", "type": "photo", "sizes": {"thumb": {"w": 150, "h": 150, "resize": "crop"}, "medium": {"w": 819, "h": 1200, "resize": "fit"}, "small": {"w": 464, "h": 680, "resize": "fit"}, "large": {"w": 1398, "h": 2048, "resize": "fit"}}}]}, "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 19895282, "id_str": "19895282", "name": "A.R.Rahman", "screen_name": "arrahman", "location": "Chennai, India", "description": "Grammy and Academy Award winning musician                           (Reluctant Tweeter. Mostly Drowned in a Parallel Galaxy)", "url": "https://t.co/eHXO9MRi96", "entities": {"url": {"urls": [{"url": "https://t.co/eHXO9MRi96", "expanded_url": "http://www.arrahman.com", "display_url": "arrahman.com", "indices": [0, 23]}]}, "description": {"urls": []}}, "protected": false, "followers_count": 19856027, "friends_count": 1, "listed_count": 11258, "created_at": "Mon Feb 02 05:53:57 +0000 2009", "favourites_count": 66, "utc_offset": 19800, "time_zone": "Chennai", "geo_enabled": false, "verified": true, "statuses_count": 4438, "lang": "en", "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "C6E2EE", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/737604036/3179cc1733a2b605d117e3661d8439ad.jpeg", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/737604036/3179cc1733a2b605d117e3661d8439ad.jpeg", "profile_background_tile": false, "profile_image_url": "http://pbs.twimg.com/profile_images/597865661264596992/NnOqToId_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/597865661264596992/NnOqToId_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/19895282/1493060067", "profile_link_color": "1F98C7", "profile_sidebar_border_color": "FFFFFF", "profile_sidebar_fill_color": "DAECF4", "profile_text_color": "663B12", "profile_use_background_image": true, "has_extended_profile": false, "default_profile": false, "default_profile_image": false, "following": true, "follow_request_sent": false, "notifications": false, "translator_type": "none"}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 180, "favorite_count": 1511, "favorited": false, "retweeted": false, "possibly_sensitive": false, "possibly_sensitive_appealable": false, "lang": "en"}
# {"created_at": "Thu Apr 19 15:21:14 +0000 2018", "id": 986988096536313856, "id_str": "986988096536313856", "text": "Check this out ! https://t.co/RLPeBR85D9", "truncated": false, "entities": {"hashtags": [], "symbols": [], "user_mentions": [], "urls": [{"url": "https://t.co/RLPeBR85D9", "expanded_url": "https://www.youtube.com/watch?v=T8H_GCH41sw&sns=em", "display_url": "youtube.com/watch?v=T8H_GC\u2026", "indices": [17, 40]}]}, "source": "<a href=\"http://www.facebook.com/twitter\" rel=\"nofollow\">Facebook</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 19895282, "id_str": "19895282", "name": "A.R.Rahman", "screen_name": "arrahman", "location": "Chennai, India", "description": "Grammy and Academy Award winning musician                           (Reluctant Tweeter. Mostly Drowned in a Parallel Galaxy)", "url": "https://t.co/eHXO9MRi96", "entities": {"url": {"urls": [{"url": "https://t.co/eHXO9MRi96", "expanded_url": "http://www.arrahman.com", "display_url": "arrahman.com", "indices": [0, 23]}]}, "description": {"urls": []}}, "protected": false, "followers_count": 19856027, "friends_count": 1, "listed_count": 11258, "created_at": "Mon Feb 02 05:53:57 +0000 2009", "favourites_count": 66, "utc_offset": 19800, "time_zone": "Chennai", "geo_enabled": false, "verified": true, "statuses_count": 4438, "lang": "en", "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "C6E2EE", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/737604036/3179cc1733a2b605d117e3661d8439ad.jpeg", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/737604036/3179cc1733a2b605d117e3661d8439ad.jpeg", "profile_background_tile": false, "profile_image_url": "http://pbs.twimg.com/profile_images/597865661264596992/NnOqToId_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/597865661264596992/NnOqToId_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/19895282/1493060067", "profile_link_color": "1F98C7", "profile_sidebar_border_color": "FFFFFF", "profile_sidebar_fill_color": "DAECF4", "profile_text_color": "663B12", "profile_use_background_image": true, "has_extended_profile": false, "default_profile": false, "default_profile_image": false, "following": true, "follow_request_sent": false, "notifications": false, "translator_type": "none"}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 141, "favorite_count": 1458, "favorited": false, "retweeted": false, "possibly_sensitive": false, "possibly_sensitive_appealable": false, "lang": "en"}
# {"created_at": "Thu Apr 19 15:06:04 +0000 2018", "id": 986984280516714496, "id_str": "986984280516714496", "text": "This is BIG NEWS\ud83d\ude2cExcited to announce my association with @mamaearthindia  as an equity investor.\u2026 https://t.co/Adn5I8HJUF", "truncated": false, "entities": {"hashtags": [], "symbols": [], "user_mentions": [{"screen_name": "mamaearthindia", "name": "MamaEarth", "id": 784570429432299520, "id_str": "784570429432299520", "indices": [57, 72]}], "urls": [{"url": "https://t.co/Adn5I8HJUF", "expanded_url": "https://www.instagram.com/p/BhwaVjJhafu/", "display_url": "instagram.com/p/BhwaVjJhafu/", "indices": [98, 121]}]}, "source": "<a href=\"http://instagram.com\" rel=\"nofollow\">Instagram</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 115341081, "id_str": "115341081", "name": "SHILPA SHETTY KUNDRA", "screen_name": "TheShilpaShetty", "location": "", "description": "Full time Mother &Wife ,Actor, entrepreneur, Yogi ,author of @greatindiandiet. Order my book https://t.co/WjHQHe2A7g\u2026", "url": "https://t.co/9SG3iOGst0", "entities": {"url": {"urls": [{"url": "https://t.co/9SG3iOGst0", "expanded_url": "http://theshilpashetty.com", "display_url": "theshilpashetty.com", "indices": [0, 23]}]}, "description": {"urls": [{"url": "https://t.co/WjHQHe2A7g", "expanded_url": "http://bit.ly/Domesticdivapr", "display_url": "bit.ly/Domesticdivapr", "indices": [93, 116]}]}}, "protected": false, "followers_count": 5693027, "friends_count": 138, "listed_count": 8626, "created_at": "Thu Feb 18 10:41:18 +0000 2010", "favourites_count": 64, "utc_offset": 19800, "time_zone": "Mumbai", "geo_enabled": true, "verified": true, "statuses_count": 5300, "lang": "en", "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "1A1B1F", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/407212316/ssk_ghb.jpg", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/407212316/ssk_ghb.jpg", "profile_background_tile": true, "profile_image_url": "http://pbs.twimg.com/profile_images/929324251458420736/bXcF9ywJ_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/929324251458420736/bXcF9ywJ_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/115341081/1516280215", "profile_link_color": "2FC2EF", "profile_sidebar_border_color": "181A1E", "profile_sidebar_fill_color": "252429", "profile_text_color": "666666", "profile_use_background_image": true, "has_extended_profile": true, "default_profile": false, "default_profile_image": false, "following": true, "follow_request_sent": false, "notifications": false, "translator_type": "none"}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 18, "favorite_count": 247, "favorited": false, "retweeted": false, "possibly_sensitive": false, "possibly_sensitive_appealable": false, "lang": "en"}
# {"created_at": "Thu Apr 19 14:02:33 +0000 2018", "id": 986968298171633664, "id_str": "986968298171633664", "text": "Kya baat hain super hero!!!! @HarshKapoor_  this looks seriously kick ass. Can\u2019t wait for the trailer.\u2026 https://t.co/PBrohnAg7z", "truncated": true, "entities": {"hashtags": [], "symbols": [], "user_mentions": [{"screen_name": "HarshKapoor_", "name": "Harshvardhan Kapoor", "id": 1695938996, "id_str": "1695938996", "indices": [29, 42]}], "urls": [{"url": "https://t.co/PBrohnAg7z", "expanded_url": "https://twitter.com/i/web/status/986968298171633664", "display_url": "twitter.com/i/web/status/9\u2026", "indices": [104, 127]}]}, "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 108936259, "id_str": "108936259", "name": "arjun rampal", "screen_name": "rampalarjun", "location": "\u00dcT: 19.166473,72.845918", "description": "Don\u2019t leave things till it\u2019s too late you are the DJ of your own Fate.", "url": null, "entities": {"description": {"urls": []}}, "protected": false, "followers_count": 4278743, "friends_count": 135, "listed_count": 5557, "created_at": "Wed Jan 27 13:27:14 +0000 2010", "favourites_count": 35, "utc_offset": 19800, "time_zone": "Mumbai", "geo_enabled": false, "verified": true, "statuses_count": 5078, "lang": "en", "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "131516", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/80660313/IMG_3902.JPG", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/80660313/IMG_3902.JPG", "profile_background_tile": true, "profile_image_url": "http://pbs.twimg.com/profile_images/930845486675881984/W9DvnF1J_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/930845486675881984/W9DvnF1J_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/108936259/1510765835", "profile_link_color": "009999", "profile_sidebar_border_color": "EEEEEE", "profile_sidebar_fill_color": "EFEFEF", "profile_text_color": "333333", "profile_use_background_image": true, "has_extended_profile": false, "default_profile": false, "default_profile_image": false, "following": true, "follow_request_sent": false, "notifications": false, "translator_type": "none"}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 9, "favorite_count": 156, "favorited": false, "retweeted": false, "possibly_sensitive": false, "possibly_sensitive_appealable": false, "lang": "en"}
# {"created_at": "Thu Apr 19 12:54:18 +0000 2018", "id": 986951120512847877, "id_str": "986951120512847877", "text": "Core training my way through the summer heat with these wooden beads...great for the back and stomach muscles. Also\u2026 https://t.co/oXpmst8eBh", "truncated": true, "entities": {"hashtags": [], "symbols": [], "user_mentions": [], "urls": [{"url": "https://t.co/oXpmst8eBh", "expanded_url": "https://twitter.com/i/web/status/986951120512847877", "display_url": "twitter.com/i/web/status/9\u2026", "indices": [117, 140]}]}, "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 31348594, "id_str": "31348594", "name": "Akshay Kumar", "screen_name": "akshaykumar", "location": "", "description": "", "url": "https://t.co/nVpOquecxs", "entities": {"url": {"urls": [{"url": "https://t.co/nVpOquecxs", "expanded_url": "http://www.facebook.com/akshaykumarofficial", "display_url": "facebook.com/akshaykumaroff\u2026", "indices": [0, 23]}]}, "description": {"urls": []}}, "protected": false, "followers_count": 26399775, "friends_count": 25, "listed_count": 14835, "created_at": "Wed Apr 15 05:23:19 +0000 2009", "favourites_count": 629, "utc_offset": 19800, "time_zone": "Mumbai", "geo_enabled": false, "verified": true, "statuses_count": 38589, "lang": "en", "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "9AE4E8", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/314184212/twitter_bg_vertical.jpg", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/314184212/twitter_bg_vertical.jpg", "profile_background_tile": false, "profile_image_url": "http://pbs.twimg.com/profile_images/841956276141711360/Yh7xHO41_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/841956276141711360/Yh7xHO41_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/31348594/1521191402", "profile_link_color": "0084B4", "profile_sidebar_border_color": "121212", "profile_sidebar_fill_color": "B3B3B3", "profile_text_color": "333333", "profile_use_background_image": true, "has_extended_profile": false, "default_profile": false, "default_profile_image": false, "following": true, "follow_request_sent": false, "notifications": false, "translator_type": "none"}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 1493, "favorite_count": 15019, "favorited": false, "retweeted": false, "possibly_sensitive": false, "possibly_sensitive_appealable": false, "lang": "en"}
# {"created_at": "Thu Apr 19 12:07:49 +0000 2018", "id": 986939423773347840, "id_str": "986939423773347840", "text": "Rivers are our lifelines and the right steps to prevent extinction must be implemented. #RiversInABottle is a great\u2026 https://t.co/EsCNmLlYoQ", "truncated": true, "entities": {"hashtags": [{"text": "RiversInABottle", "indices": [88, 104]}], "symbols": [], "user_mentions": [], "urls": [{"url": "https://t.co/EsCNmLlYoQ", "expanded_url": "https://twitter.com/i/web/status/986939423773347840", "display_url": "twitter.com/i/web/status/9\u2026", "indices": [117, 140]}]}, "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 135421739, "id_str": "135421739", "name": "Sachin Tendulkar", "screen_name": "sachin_rt", "location": "\u00dcT: 18.986431,72.823769", "description": "Proud Indian", "url": "https://t.co/tRoTtzKKst", "entities": {"url": {"urls": [{"url": "https://t.co/tRoTtzKKst", "expanded_url": "http://pbl.cm/100mbapp", "display_url": "pbl.cm/100mbapp", "indices": [0, 23]}]}, "description": {"urls": []}}, "protected": false, "followers_count": 25666553, "friends_count": 78, "listed_count": 22902, "created_at": "Wed Apr 21 07:42:23 +0000 2010", "favourites_count": 71, "utc_offset": null, "time_zone": null, "geo_enabled": false, "verified": true, "statuses_count": 2059, "lang": "en", "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "C0DEED", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_image_url": "http://pbs.twimg.com/profile_images/2504398687/344204969_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/2504398687/344204969_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/135421739/1409651897", "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "has_extended_profile": true, "default_profile": true, "default_profile_image": false, "following": true, "follow_request_sent": false, "notifications": false, "translator_type": "regular"}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": true, "quoted_status_id": 986906208039731201, "quoted_status_id_str": "986906208039731201", "quoted_status": {"created_at": "Thu Apr 19 09:55:50 +0000 2018", "id": 986906208039731201, "id_str": "986906208039731201", "text": "Our rivers are depleting, but are we aware of the impact that it will have on our future? Watch the video to know a\u2026 https://t.co/dYZ4xJYjr7", "truncated": true, "entities": {"hashtags": [], "symbols": [], "user_mentions": [], "urls": [{"url": "https://t.co/dYZ4xJYjr7", "expanded_url": "https://twitter.com/i/web/status/986906208039731201", "display_url": "twitter.com/i/web/status/9\u2026", "indices": [117, 140]}]}, "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 847199904, "id_str": "847199904", "name": "Livpure", "screen_name": "Livpurewater", "location": "", "description": "Livpure Private Limited is a manufacturing unit with focus on developing, researching & refining purification systems. https://t.co/pNbgIpYRJr", "url": "https://t.co/OQRBZabgWx", "entities": {"url": {"urls": [{"url": "https://t.co/OQRBZabgWx", "expanded_url": "https://www.livpure.in/", "display_url": "livpure.in", "indices": [0, 23]}]}, "description": {"urls ...
# {"created_at": "Thu Apr 19 11:22:04 +0000 2018", "id": 986927908412272645, "id_str": "986927908412272645", "text": "My secret recipe of this crunchy #Protein chikki is ready to devour. It is high in protein, essential fats and anti\u2026 https://t.co/Q80Y9JfLvK", "truncated": true, "entities": {"hashtags": [{"text": "Protein", "indices": [33, 41]}], "symbols": [], "user_mentions": [], "urls": [{"url": "https://t.co/Q80Y9JfLvK", "expanded_url": "https://twitter.com/i/web/status/986927908412272645", "display_url": "twitter.com/i/web/status/9\u2026", "indices": [117, 140]}]}, "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 115341081, "id_str": "115341081", "name": "SHILPA SHETTY KUNDRA", "screen_name": "TheShilpaShetty", "location": "", "description": "Full time Mother &Wife ,Actor, entrepreneur, Yogi ,author of @greatindiandiet. Order my book https://t.co/WjHQHe2A7g\u2026", "url": "https://t.co/9SG3iOGst0", "entities": {"url": {"urls": [{"url": "https://t.co/9SG3iOGst0", "expanded_url": "http://theshilpashetty.com", "display_url": "theshilpashetty.com", "indices": [0, 23]}]}, "description": {"urls": [{"url": "https://t.co/WjHQHe2A7g", "expanded_url": "http://bit.ly/Domesticdivapr", "display_url": "bit.ly/Domesticdivapr", "indices": [93, 116]}]}}, "protected": false, "followers_count": 5693027, "friends_count": 138, "listed_count": 8626, "created_at": "Thu Feb 18 10:41:18 +0000 2010", "favourites_count": 64, "utc_offset": 19800, "time_zone": "Mumbai", "geo_enabled": true, "verified": true, "statuses_count": 5300, "lang": "en", "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "1A1B1F", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/407212316/ssk_ghb.jpg", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/407212316/ssk_ghb.jpg", "profile_background_tile": true, "profile_image_url": "http://pbs.twimg.com/profile_images/929324251458420736/bXcF9ywJ_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/929324251458420736/bXcF9ywJ_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/115341081/1516280215", "profile_link_color": "2FC2EF", "profile_sidebar_border_color": "181A1E", "profile_sidebar_fill_color": "252429", "profile_text_color": "666666", "profile_use_background_image": true, "has_extended_profile": true, "default_profile": false, "default_profile_image": false, "following": true, "follow_request_sent": false, "notifications": false, "translator_type": "none"}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 22, "favorite_count": 353, "favorited": false, "retweeted": false, "possibly_sensitive": false, "possibly_sensitive_appealable": false, "lang": "en"}
# {"created_at": "Thu Apr 19 10:39:31 +0000 2018", "id": 986917199540400129, "id_str": "986917199540400129", "text": "The two favourites and my favourite track from the film #BadumbaaZumbaa. Check it out. @chintskap @SrBachchan\u2026 https://t.co/ZheS1Q25dT", "truncated": true, "entities": {"hashtags": [{"text": "BadumbaaZumbaa", "indices": [56, 71]}], "symbols": [], "user_mentions": [{"screen_name": "chintskap", "name": "Rishi Kapoor", "id": 105710210, "id_str": "105710210", "indices": [87, 97]}, {"screen_name": "SrBachchan", "name": "Amitabh Bachchan", "id": 145125358, "id_str": "145125358", "indices": [98, 109]}], "urls": [{"url": "https://t.co/ZheS1Q25dT", "expanded_url": "https://twitter.com/i/web/status/986917199540400129", "display_url": "twitter.com/i/web/status/9\u2026", "indices": [111, 134]}]}, "source": "<a href=\"http://tapbots.com/tweetbot\" rel=\"nofollow\">Tweetbot for i\u039fS</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 87170183, "id_str": "87170183", "name": "Abhishek Bachchan", "screen_name": "juniorbachchan", "location": "Mumbai, India", "description": "Actor, Sports fan.", "url": null, "entities": {"description": {"urls": []}}, "protected": false, "followers_count": 13889918, "friends_count": 388, "listed_count": 14617, "created_at": "Tue Nov 03 11:29:22 +0000 2009", "favourites_count": 371, "utc_offset": -36000, "time_zone": "Hawaii", "geo_enabled": false, "verified": true, "statuses_count": 27409, "lang": "en", "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "131516", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif", "profile_background_tile": false, "profile_image_url": "http://pbs.twimg.com/profile_images/719427633117671425/J5wKAQlQ_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/719427633117671425/J5wKAQlQ_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/87170183/1518284335", "profile_link_color": "009999", "profile_sidebar_border_color": "EEEEEE", "profile_sidebar_fill_color": "EFEFEF", "profile_text_color": "333333", "profile_use_background_image": true, "has_extended_profile": false, "default_profile": false, "default_profile_image": false, "following": true, "follow_request_sent": false, "notifications": false, "translator_type": "none"}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 125, "favorite_count": 993, "favorited": false, "retweeted": false, "possibly_sensitive": false, "possibly_sensitive_appealable": false, "lang": "en"}
# {"created_at": "Thu Apr 19 10:35:35 +0000 2018", "id": 986916210079039488, "id_str": "986916210079039488", "text": "The fastest way to make ur dreams come true is to wake up &amp; get to work. #workhard #noshortcuts #dreambig\u2026 https://t.co/60qcK1q6gS", "truncated": true, "entities": {"hashtags": [{"text": "workhard", "indices": [77, 86]}, {"text": "noshortcuts", "indices": [87, 99]}, {"text": "dreambig", "indices": [100, 109]}], "symbols": [], "user_mentions": [], "urls": [{"url": "https://t.co/60qcK1q6gS", "expanded_url": "https://twitter.com/i/web/status/986916210079039488", "display_url": "twitter.com/i/web/status/9\u2026", "indices": [111, 134]}]}, "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 86254626, "id_str": "86254626", "name": "Preity zinta", "screen_name": "realpreityzinta", "location": "Catch me if you can....", "description": "Actor, Producer, Writer, Entrepreneur , Human Being and Cricket fan!", "url": "https://t.co/sRoWGMCPv4", "entities": {"url": {"urls": [{"url": "https://t.co/sRoWGMCPv4", "expanded_url": "https://www.facebook.com/officialpz", "display_url": "facebook.com/officialpz", "indices": [0, 23]}]}, "description": {"urls": []}}, "protected": false, "followers_count": 4275566, "friends_count": 93, "listed_count": 15673, "created_at": "Fri Oct 30 06:30:11 +0000 2009", "favourites_count": 782, "utc_offset": null, "time_zone": null, "geo_enabled": false, "verified": true, "statuses_count": 18658, "lang": "en", "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "131516", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/279547513/2rcwtw7.jpg", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/279547513/2rcwtw7.jpg", "profile_background_tile": false, "profile_image_url": "http://pbs.twimg.com/profile_images/917631983370461184/bXQjpkDe_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/917631983370461184/bXQjpkDe_normal.jpg", "profile_link_color": "009999", "profile_sidebar_border_color": "EEEEEE", "profile_sidebar_fill_color": "EFEFEF", "profile_text_color": "333333", "profile_use_background_image": true, "has_extended_profile": false, "default_profile": false, "default_profile_image": false, "following": true, "follow_request_sent": false, "notifications": false, "translator_type": "none"}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 110, "favorite_count": 899, "favorited": false, "retweeted": false, "possibly_sensitive": true, "possibly_sensitive_appealable": false, "lang": "en"}

# %%
for friend in tweepy.Cursor(api.friends).items():
    process_or_store(friend._json)
# Out:
# {"id": 338934670, "id_str": "338934670", "name": "The Dewarists", "screen_name": "dewarists", "location": "", "description": "Every note of this #LiveTrue journey will inspire you to pursue your passion. #TheDewarists Season 5 is here https://t.co/pKXjYgqMyh.\n#Dewars #TrueScotch", "url": null, "entities": {"description": {"urls": [{"url": "https://t.co/pKXjYgqMyh", "expanded_url": "http://bit.ly/2gfsUuk", "display_url": "bit.ly/2gfsUuk", "indices": [109, 132]}]}}, "protected": false, "followers_count": 23393, "friends_count": 1460, "listed_count": 116, "created_at": "Wed Jul 20 09:55:28 +0000 2011", "favourites_count": 2646, "utc_offset": 19800, "time_zone": "New Delhi", "geo_enabled": true, "verified": true, "statuses_count": 9156, "lang": "en", "status": {"created_at": "Fri Aug 11 11:52:37 +0000 2017", "id": 895976243538968576, "id_str": "895976243538968576", "text": "@bakedsamosa Hey Rahul, please email your request on contactus@dewarsindia.com, our team will get back to you as soon as possible.", "truncated": false, "entities": {"hashtags": [], "symbols": [], "user_mentions": [{"screen_name": "bakedsamosa", "name": "rahulkaveeshwar", "id": 90172002, "id_str": "90172002", "indices": [0, 12]}], "urls": []}, "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "in_reply_to_status_id": 857451263495163906, "in_reply_to_status_id_str": "857451263495163906", "in_reply_to_user_id": 90172002, "in_reply_to_user_id_str": "90172002", "in_reply_to_screen_name": "bakedsamosa", "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 0, "favorite_count": 0, "favorited": false, "retweeted": false, "lang": "en"}, "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "660000", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/541174864392892416/m1z_wAdJ.jpeg", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/541174864392892416/m1z_wAdJ.jpeg", "profile_background_tile": false, "profile_image_url": "http://pbs.twimg.com/profile_images/779303853766250496/FZWGUgI8_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/779303853766250496/FZWGUgI8_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/338934670/1501159322", "profile_link_color": "660000", "profile_sidebar_border_color": "000000", "profile_sidebar_fill_color": "530304", "profile_text_color": "FAFAFA", "profile_use_background_image": true, "has_extended_profile": false, "default_profile": false, "default_profile_image": false, "following": true, "live_following": false, "follow_request_sent": false, "notifications": false, "muting": false, "blocking": false, "blocked_by": false, "translator_type": "none"}
# {"id": 75233664, "id_str": "75233664", "name": "Coshish", "screen_name": "Coshish", "location": "Mumbai", "description": "The Official Coshish Twitter Page", "url": "http://t.co/9vYfWshib9", "entities": {"url": {"urls": [{"url": "http://t.co/9vYfWshib9", "expanded_url": "http://www.facebook.com/coshish", "display_url": "facebook.com/coshish", "indices": [0, 22]}]}, "description": {"urls": []}}, "protected": false, "followers_count": 812, "friends_count": 116, "listed_count": 7, "created_at": "Fri Sep 18 08:33:38 +0000 2009", "favourites_count": 355, "utc_offset": 19800, "time_zone": "Mumbai", "geo_enabled": true, "verified": false, "statuses_count": 1205, "lang": "en", "status": {"created_at": "Mon Jan 15 10:12:01 +0000 2018", "id": 952845820310663168, "id_str": "952845820310663168", "text": "RT @ashwinwashere: Yesterday with @coshish at SIMS Pune was a total blast :)\n----\n#coshish #coshishjaarirahe #sims\u2026 https://t.co/WGIiq11iFd", "truncated": false, "entities": {"hashtags": [{"text": "coshish", "indices": [82, 90]}, {"text": "coshishjaarirahe", "indices": [91, 108]}, {"text": "sims", "indices": [109, 114]}], "symbols": [], "user_mentions": [{"screen_name": "ashwinwashere", "name": "Ashwin Sharma", "id": 38807733, "id_str": "38807733", "indices": [3, 17]}, {"screen_name": "Coshish", "name": "Coshish", "id": 75233664, "id_str": "75233664", "indices": [34, 42]}], "urls": [{"url": "https://t.co/WGIiq11iFd", "expanded_url": "https://www.instagram.com/p/Bd9zUPhlVAZ/", "display_url": "instagram.com/p/Bd9zUPhlVAZ/", "indices": [116, 139]}]}, "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "geo": null, "coordinates": null, "place": null, "contributors": null, "retweeted_status": {"created_at": "Mon Jan 15 09:48:51 +0000 2018", "id": 952839991390097408, "id_str": "952839991390097408", "text": "Yesterday with @coshish at SIMS Pune was a total blast :)\n----\n#coshish #coshishjaarirahe #sims\u2026 https://t.co/WGIiq11iFd", "truncated": false, "entities": {"hashtags": [{"text": "coshish", "indices": [63, 71]}, {"text": "coshishjaarirahe", "indices": [72, 89]}, {"text": "sims", "indices": [90, 95]}], "symbols": [], "user_mentions": [{"screen_name": "Coshish", "name": "Coshish", "id": 75233664, "id_str": "75233664", "indices": [15, 23]}], "urls": [{"url": "https://t.co/WGIiq11iFd", "expanded_url": "https://www.instagram.com/p/Bd9zUPhlVAZ/", "display_url": "instagram.com/p/Bd9zUPhlVAZ/", "indices": [97, 120]}]}, "source": "<a href=\"http://instagram.com\" rel=\"nofollow\">Instagram</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "geo": {"type": "Point", "coordinates": [18.55280833, 73.84405667]}, "coordinates": {"type": "Point", "coordinates": [73.84405667, 18.55280833]}, "place": {"id": "5c0761bdffa0cb64", "url": "https://api.twitter.com/1.1/geo/id/5c0761bdffa0cb64.json", "place_type": "city", "name": "Pune", "full_name": "Pune, India", "country_code": "IN", "country": "India", "contained_within": [], "bounding_box": {"type": "Polygon", "coordinates": [[[73.8031065, 18.4571648], [73.9656571, 18.4571648], [73.9656571, 18.5843633], [73.8031065, 18.5843633]]]}, "attributes": {}}, "contributors": null, "is_quote_status": false, "retweet_count": 1, "favorite_count": 1, "favorited": false, "retweeted": false, "possibly_sensitive": false, "lang": "en"}, "is_quote_status": false, "retweet_count": 1, "favorite_count": 0, "favorited": false, "retweeted": false, "possibly_sensitive": false, "lang": "en"}, "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "1A1B1F", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme9/bg.gif", "pro ...
# {"id": 108936259, "id_str": "108936259", "name": "arjun rampal", "screen_name": "rampalarjun", "location": "\u00dcT: 19.166473,72.845918", "description": "Don\u2019t leave things till it\u2019s too late you are the DJ of your own Fate.", "url": null, "entities": {"description": {"urls": []}}, "protected": false, "followers_count": 4278744, "friends_count": 135, "listed_count": 5557, "created_at": "Wed Jan 27 13:27:14 +0000 2010", "favourites_count": 35, "utc_offset": 19800, "time_zone": "Mumbai", "geo_enabled": false, "verified": true, "statuses_count": 5078, "lang": "en", "status": {"created_at": "Thu Apr 19 14:02:33 +0000 2018", "id": 986968298171633664, "id_str": "986968298171633664", "text": "Kya baat hain super hero!!!! @HarshKapoor_  this looks seriously kick ass. Can\u2019t wait for the trailer.\u2026 https://t.co/PBrohnAg7z", "truncated": true, "entities": {"hashtags": [], "symbols": [], "user_mentions": [{"screen_name": "HarshKapoor_", "name": "Harshvardhan Kapoor", "id": 1695938996, "id_str": "1695938996", "indices": [29, 42]}], "urls": [{"url": "https://t.co/PBrohnAg7z", "expanded_url": "https://twitter.com/i/web/status/986968298171633664", "display_url": "twitter.com/i/web/status/9\u2026", "indices": [104, 127]}]}, "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 9, "favorite_count": 156, "favorited": false, "retweeted": false, "possibly_sensitive": false, "lang": "en"}, "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "131516", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/80660313/IMG_3902.JPG", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/80660313/IMG_3902.JPG", "profile_background_tile": true, "profile_image_url": "http://pbs.twimg.com/profile_images/930845486675881984/W9DvnF1J_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/930845486675881984/W9DvnF1J_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/108936259/1510765835", "profile_link_color": "009999", "profile_sidebar_border_color": "EEEEEE", "profile_sidebar_fill_color": "EFEFEF", "profile_text_color": "333333", "profile_use_background_image": true, "has_extended_profile": false, "default_profile": false, "default_profile_image": false, "following": true, "live_following": false, "follow_request_sent": false, "notifications": false, "muting": false, "blocking": false, "blocked_by": false, "translator_type": "none"}
# {"id": 115341081, "id_str": "115341081", "name": "SHILPA SHETTY KUNDRA", "screen_name": "TheShilpaShetty", "location": "", "description": "Full time Mother &Wife ,Actor, entrepreneur, Yogi ,author of @greatindiandiet. Order my book https://t.co/WjHQHe2A7g\u2026", "url": "https://t.co/9SG3iOGst0", "entities": {"url": {"urls": [{"url": "https://t.co/9SG3iOGst0", "expanded_url": "http://thesh
normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/318307196/Kareena_Kapoor_50x50_normal.jpg", "profile_link_color": "B40B43", "profile_sidebar_border_color": "CC3366", "profile_sidebar_fill_color": "E5507E", "profile_text_color": "362720", "profile_use_background_image": true, "has_extended_profile": false, "default_profile": false, "default_profile_image": false, "following": true, "live_following": false, "follow_request_sent": false, "notifications": false, "muting": false, "blocking": false, "blocked_by": false, "translator_type": "none"}
# {"id": 113419517, "id_str": "113419517", "name": "Hrithik Roshan", "screen_name": "iHrithik", "location": "\u00dcT: 19.109458,72.825842", "description": "Man on mission- to live the best life possible come what may.", "url": null, "entities": {"description": {"urls": []}}, "protected": false, "followers_count": 23352916, "friends_count": 87, "listed_count": 17110, "created_at": "Thu Feb 11 18:06:33 +0000 2010", "favourites_count": 121, "utc_offset": 19800, "time_zone": "Mumbai", "geo_enabled": false, "verified": true, "statuses_count": 4501, "lang": "en", "status": {"created_at": "Thu Apr 19 07:45:55 +0000 2018", "id": 986873513268002818, "id_str": "986873513268002818", "text": "You are what you eat. But I guess we all get a little overwhelmed with the choices , what\u2019s good , what\u2019s bad. Toda\u2026 https://t.co/to95RsDpmI", "truncated": true, "entities": {"hashtags": [], "symbols": [], "user_mentions": [], "urls": [{"url": "https://t.co/to95RsDpmI", "expanded_url": "https://twitter.com/i/web/status/986873513268002818", "display_url": "twitter.com/i/web/status/9\u2026", "indices": [117, 140]}]}, "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": true, "quoted_status_id": 986861001474695168, "quoted_status_id_str": "986861001474695168", "retweet_count": 490, "favorite_count": 4647, "favorited": false, "retweeted": false, "possibly_sensitive": false, "lang": "en"}, "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "131516", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/75983216/us22.jpg", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/75983216/us22.jpg", "profile_background_tile": true, "profile_image_url": "http://pbs.twimg.com/profile_images/852874627181367297/BhCGvY6d_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/852874627181367297/BhCGvY6d_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/113419517/1459453794", "profile_link_color": "009999", "profile_sidebar_border_color": "EEEEEE", "profile_sidebar_fill_color": "EFEFEF", "profile_text_color": "333333", "profile_use_background_image": true, "has_extended_profile": false, "default_profile": false, "default_profile_image": false, "following": true, "live_following": false, "follow_request_sent": false, "notifications": false, "muting": false, "blocking": false, "blocked_by": false, "translator_type": "none"}
# {"id": 101311381, "id_str": "101311381", "name": "Shah Rukh Khan", "screen_name": "iamsrk", "location": "", "description": "", "url": "http://t.co/rgTV59DRJ7", "entities": {"url": {"urls": [{"url": "http://t.co/rgTV59DRJ7", "expanded_url": "https://twitter.com/iamsrk", "display_url": "twitter.com/iamsrk", "indices": [0, 22]}]}, "description": {"urls": []}}, "protected": false, "followers_count": 34965439, "friends_count": 78, "listed_count": 29449, "created_at": "Sat Jan 02 20:55:43 +0000 2010", "favourites_count": 18, "utc_offset": -28800, "time_zone": "Alaska", "geo_enabled": true, "verified": true, "statuses_count": 57234, "lang": "en", "status": {"created_at": "Wed Apr 18 23:28:06 +0000 2018", "id": 986748234851913728, "id_str": "986748234851913728", "text": "So glad to see the babies r settling in, Curran Mavi &amp; Gill. Dk Piyush Rana Kuldeep Robbie all showing the way to t\u2026 https://t.co/fCGfzHj7aw", "truncated": true, "entities": {"hashtags": [], "symbols": [], "user_mentions": [], "urls": [{"url": "https://t.co/fCGfzHj7aw", "expanded_url": "https://twitter.com/i/web/status/986748234851913728", "display_url": "twitter.com/i/web/status/9\u2026", "indices": [121, 144]}]}, "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 4203, "favorite_count": 32780, "favorited": false, "retweeted": false, "lang": "en"}, "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "022330", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/137435577/new1.jpg", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/137435577/new1.jpg", "profile_background_tile": true, "profile_image_url": "http://pbs.twimg.com/profile_images/661679664/keep_it_onn_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/661679664/keep_it_onn_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/101311381/1454256204", "profile_link_color": "0084B4", "profile_sidebar_border_color": "A8C7F7", "profile_sidebar_fill_color": "C0DFEC", "profile_text_color": "333333", "profile_use_background_image": true, "has_extended_profile": false, "default_profile": false, "default_profile_image": false, "following": true, "live_following": false, "follow_request_sent": false, "notifications": false, "muting": false, "blocking": false, "blocked_by": false, "translator_type": "regular"}
# {"id": 97865628, "id_str": "97865628", "name": "Farhan Akhtar", "screen_name": "FarOutAkhtar", "location": "Mumbai, India", "description": "Writer. Director. Actor. Singer/Songwriter. Founder- @MardOfficial Initiative | @UN_Women Goodwill Ambassador(South Asia)", "url": "https://t.co/dglUzw4gLn", "entities": {"url": {"urls": [{"url": "https://t.co/dglUzw4gLn", "expanded_url": "http://www.excelmovies.com", "display_url": "excelmovies.com", "indices": [0, 23]}]}, "description": {"urls": []}}, "protected": false, "followers_count": 11516762, "friends_count": 272, "listed_count": 9109, "created_at": "Sat Dec 19 09:37:49 +0000 2009", "favourites_count": 2966, "utc_offset": 19800, "time_zone": "New Delhi", "geo_enabled": true, "verified": true, "statuses_count": 6963, "lang": "en", "status": {"created_at": "Tue Apr 17 13:13:25 +0000 2018", "id": 986231156172623873, "id_str": "986231156172623873", "text": "Life\u2019s an adventure and you\u2019re going to need the right ride.. here\u2019s mine. jeepindia\u2026 https://t.co/fNy5eqHkAo", "truncated": false, "entities": {"hashtags": [], "symbols": [], "user_mentions": [], "urls": [{"url": "https://t.co/fNy5eqHkAo", "expanded_url": "https://www.instagram.com/p/BhrD3OnhU52/", "display_url": "instagram.com/p/BhrD3OnhU52/", "indices": [86, 109]}]}, "source": "<a href=\"http://instagram.com\" rel=\"nofollow\">Instagram</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 22, "favorite_count": 609, "favorited": false, "retweeted": false, "possibly_sensitive": false, "lang": "en"}, "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "131516", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/569899922141368320/ozRjzlG5.jpeg", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/569899922141368320/ozRjzlG5.jpeg", "profile_background_tile": true, "profile_image_url": "http://pbs.twimg.com/profile_images/911185584076607488/tSZ09eZ7_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/911185584076607488/tSZ09eZ7_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/97865628/1496500663", "profile_link_color": "009999", "profile_sidebar_border_color": "EEEEEE", "profile_sidebar_fill_color": "EFEFEF", "profile_text_color": "333333", "profile_use_background_image": true, "has_extended_profile": true, "default_profile": false, "default_profile_image": false, "following": true, "live_following": false, "follow_request_sent": false, "notifications": false, "muting": false, "blocking": false, "blocked_by": false, "translator_type": "none"}
profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "has_extended_profile": true, "default_profile": true, "default_profile_image": false, "following": true, "live_following": false, "follow_request_sent": false, "notifications": false, "muting": false, "blocking": false, "blocked_by": false, "translator_type": "regular"}
# {"id": 88856792, "id_str": "88856792", "name": "Aamir Khan", "screen_name": "aamir_khan", "location": "Mumbai", "description": "Actor.", "url": "https://t.co/l1dUhQjS8Y", "entities": {"url": {"urls": [{"url": "https://t.co/l1dUhQjS8Y", "expanded_url": "http://www.aamirkhan.com", "display_url": "aamirkhan.com", "indices": [0, 23]}]}, "description": {"urls": []}}, "protected": false, "followers_count": 23195796, "friends_count": 9, "listed_count": 20377, "created_at": "Tue Nov 10 05:08:56 +0000 2009", "favourites_count": 15, "utc_offset": 19800, "time_zone": "Mumbai", "geo_enabled": true, "verified": true, "statuses_count": 547, "lang": "en", "status": {"created_at": "Mon Apr 09 06:17:09 +0000 2018", "id": 983227294490673152, "id_str": "983227294490673152", "text": "Come be a part of the movement.\nlove. \na \nhttps://t.co/n21Rd9g4J5\n#Jalmitra #shramadaan https://t.co/YJ77Dw1OgI", "truncated": false, "entities": {"hashtags": [{"text": "Jalmitra", "indices": [66, 75]}, {"text": "shramadaan", "indices": [76, 87]}], "symbols": [], "user_mentions": [], "urls": [{"url": "https://t.co/n21Rd9g4J5", "expanded_url": "https://jalmitra.paanifoundation.in/", "display_url": "jalmitra.paanifoundation.in", "indices": [42, 65]}], "media": [{"id": 983226168856920065, "id_str": "983226168856920065", "indices": [88, 111], "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/983226168856920065/pu/img/Si7TVIsAz8Z4djCn.jpg", "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/983226168856920065/pu/img/Si7TVIsAz8Z4djCn.jpg", "url": "https://t.co/YJ77Dw1OgI", "display_url": "pic.twitter.com/YJ77Dw1OgI", "expanded_url": "https://twitter.com/aamir_khan/status/983227294490673152/video/1", "type": "photo", "sizes": {"thumb": {"w": 150, "h": 150, "resize": "crop"}, "small": {"w": 640, "h": 352, "resize": "fit"}, "medium": {"w": 640, "h": 352, "resize": "fit"}, "large": {"w": 640, "h": 352, "resize": "fit"}}}]}, "extended_entities": {"media": [{"id": 983226168856920065, "id_str": "983226168856920065", "indices": [88, 111], "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/983226168856920065/pu/img/Si7TVIsAz8Z4djCn.jpg", "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/983226168856920065/pu/img/Si7TVIsAz8Z4djCn.jpg", "url": "https://t.co/YJ77Dw1OgI", "display_url": "pic.twitter.com/YJ77Dw1OgI", "expanded_url": "https://twitter.com/aamir_khan/status/983227294490673152/video/1", "type": "video", "sizes": {"thumb": {"w": 150, "h": 150, "resize": "crop"}, "small": {"w": 640, "h": 352, "resize": "fit"}, "medium": {"w": 640, "h": 352, "resize": "fit"}, "large": {"w": 640, "h": 352, "resize": "fit"}}, "video_info": {"aspect_ratio": [20, 11], "duration_millis": 59322, "variants": [{"bitrate": 256000, "content_type": "video/mp4", "url": "https://video.twimg.com/ext_tw_video/983226168856920065/pu/vid/326x180/swNrvislAC5LnQtL.mp4"}, {"content_type": "application/x-mpegURL", "url": "https://video.twimg.com/ext_tw_video/983226168856920065/pu/pl/8Rb7QNZ1mPJ2qFl7.m3u8"}]}, "additional_media_info": {"title": "Jalmitra", "description": "", "embeddable": true, "monetizable": false}}]}, "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 2595, "favorite_count": 18061, "favorited": false, "retweeted": false, "possibly_sensitive": false, "lang": "en"}, "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "C0DEED", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/120221159/twit-bg-new1.jpg", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/120221159/twit-bg-new1.jpg", "profile_background_tile": false, "profile_image_url": " ...
# {"id": 92726549, "id_str": "92726549", "name": "Genelia Deshmukh", "screen_name": "geneliad", "location": "\u00dcT: 19.087244,72.872297", "description": "", "url": "https://t.co/XX1dotGCXo", "entities": {"url": {"urls": [{"url": "https://t.co/XX1dotGCXo", "expanded_url": "https://twitter.com/geneliad", "display_url": "twitter.com/geneliad", "indices": [0, 23]}]}, "description": {"urls": []}}, "protected": false, "followers_count": 4842966, "friends_count": 127, "listed_count": 9080, "created_at": "Thu Nov 26 10:16:23 +0000 2009", "favourites_count": 52, "utc_offset": 19800, "time_zone": "New Delhi", "geo_enabled": false, "verified": true, "statuses_count": 6911, "lang": "en", "status": {"created_at": "Thu Apr 19 02:57:07 +0000 2018", "id": 986800834116751360, "id_str": "986800834116751360", "text": "RT @minimathur: This man was seen hitting the dog near Iskon exit on Juhu beach.  He refused to give me the owners no.  Hope this reaches t\u2026", "truncated": false, "entities": {"hashtags": [], "symbols": [], "user_mentions": [{"screen_name": "minimathur", "name": "Mini Mathur", "id": 58761257, "id_str": "58761257", "indices": [3, 14]}], "urls": []}, "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "geo": null, "coordinates": null, "place": null, "contributors": null, "retweeted_status": {"created_at": "Wed Apr 18 16:51:55 +0000 2018", "id": 986648531250360322, "id_str": "986648531250360322", "text": "This man was seen hitting the dog near Iskon exit on Juhu beach.  He refused to give me the owners no.  Hope this r\u2026 https://t.co/ONK3K19cVo", "truncated": true, "entities": {"hashtags": [], "symbols": [], "user_mentions": [], "urls": [{"url": "https://t.co/ONK3K19cVo", "expanded_url": "https://twitter.com/i/web/status/986648531250360322", "display_url": "twitter.com/i/web/status/9\u2026", "indices": [117, 140]}]}, "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 537, "favorite_count": 1243, "favorited": false, "retweeted": false, "possibly_sensitive": false, "lang": "en"}, "is_quote_status": false, "retweet_count": 537, "favorite_count": 0, "favorited": false, "retweeted": false, "lang": "en"}, "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "131516", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/163018078/5.jpg", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/163018078/5.jpg", "profile_background_tile": false, "profile_image_url": "http://pbs.twimg.com/profile_images/976651286841044992/74Ak5_Wf_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/976651286841044992/74Ak5_Wf_normal.jpg", "profile_link_color": "009999", "profile_sidebar_border_color": "EEEEEE", "profile_sidebar_fill_color": "EFEFEF", "profile_text_color": "333333", "profile_use_background_image": true, "has_extended_profile": false, "default_profile": false, "default_profile_image": false, "following": true, "live_following": false, "follow_request_sent": false, "notifications": false, "muting": false, "blocking": false, "blocked_by": false, "translator_type": "none"}
# {"id": 128155589, "id_str": "128155589", "name": "Vijay Mallya", "screen_name": "TheVijayMallya", "location": "India", "description": "Former Member of Parliament, India, Chairman, The UB Group, Co-owner & Team Principal Sahara Force India Formula 1", "url": "https://t.co/nxSc7BDRNr", "entities": {"url": {"urls": [{"url": "https://t.co/nxSc7BDRNr", "expanded_url": "https://www.twitter.com/thevijaymallya", "display_url": "twitter.com/thevijaymallya", "indices": [0, 23]}]}, "description": {"urls": []}}, "protected": false, "followers_count": 6038950, "friends_count": 221, "listed_count": 25580, "created_at": "Wed Mar 31 07:48:39 +0000 2010", "favourites_count": 173, "utc_offset": 19800, "time_zone": "New Delhi", "geo_enabled": false, "verified": true, "statuses_count": 11560, "lang": "en", "status": {"created_at": "Wed Apr 18 18:40:56 +0000 2018", "id": 986675967597924355, "id_str": "986675967597924355", "text": "RT @HeroSuperCupInd: We are all set for a mega final on Friday. It's @eastbengalfc vs @bengalurufc #KEBvBFC #HeroSuperCup https://t.co/KMIJ\u2026", "truncated": false, "entities": {"hashtags": [{"text": "KEBvBFC", "indices": [99, 107]}, {"text": "HeroSuperCup", "indices": [108, 121]}], "symbols": [], "user_mentions": [{"screen_name": "HeroSuperCupInd", "name": "Hero Super Cup", "id": 974579572380323841, "id_str": "974579572380323841", "indices": [3, 19]}, {"screen_name": "eastbengalfc", "name": "KF East Bengal", "id": 170769424, "id_str": "170769424", "indices": [69, 82]}, {"screen_name": "bengalurufc", "name": "Bengaluru FC", "id": 1563626983, "id_str": "1563626983", "indices": [86, 98]}], "urls": []}, "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "geo": null, "coordinates": null, "place": null, "contributors": null, "retweeted_status": {"created_at": "Tue Apr 17 14:48:07 +0000 2018", "id": 986254989063471104, "id_str": "986254989063471104", "text": "We are all set for a mega final on Friday. It's @eastbengalfc vs @bengalurufc #KEBvBFC #HeroSuperCup https://t.co/KMIJYe1JuE", "truncated": false, "entities": {"hashtags": [{"text": "KEBvBFC", "indices": [78, 86]}, {"text": "HeroSuperCup", "indices": [87, 100]}], "symbols": [], "user_mentions": [{"screen_name": "eastbengalfc", "name": "KF East Bengal", "id": 170769424, "id_str": "170769424", "indices": [48, 61]}, {"screen_name": "bengalurufc", "name": "Bengaluru FC", "id": 1563626983, "id_str": "1563626983", "indices": [65, 77]}], "urls": [], "media": [{"id": 986253786585776135, "id_str": "986253786585776135", "indices": [101, 124], "media_url": "http://pbs.twimg.com/media/Da_gl-_UQAcD8yR.jpg", "media_url_https": "https://pbs.twimg.com/media/Da_gl-_UQAcD8yR.jpg", "url": "https://t.co/KMIJYe1JuE", "display_url": "pic.twitter.com/KMIJYe1JuE", "expanded_url": "https://twitter.com/HeroSuperCupInd/status/986254989063471104/photo/1", "type": "photo", "sizes": {"thumb": {"w": 150, "h": 150, "resize": "crop"}, "large": {"w": 1280, "h": 720, "resize": "fit"}, "small": {"w": 680, "h": 383, "resize": "fit"}, "medium": {"w": 1200, "h": 675, "resize": "fit"}}}]}, "extended_entities": {"media": [{"id": 986253786585776135, "id_str": "986253786585776135", "indices": [101, 124], "media_url": "http://pbs.twimg.com/media/Da_gl-_UQAcD8yR.jpg", "media_url_https": "https://pbs.twimg.com/media/Da_gl-_UQAcD8yR.jpg", "url": "https://t.co/KMIJYe1JuE", "display_url": "pic.twitter.com/KMIJYe1JuE", "expanded_url": "https://twitter.com/HeroSuperCupInd/status/986254989063471104/photo/1", "type": "photo", "sizes": {"thumb": {"w": 150, "h": 150, "resize": "crop"}, "large": {"w": 1280, "h": 720, "resize": "fit"}, "small": {"w": 680, "h": 383, "resize": "fit"}, "medium": {"w": 1200, "h": 675, "resize": "fit"}}}]}, "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", ...
# {"id": 92708272, "id_str": "92708272", "name": "Mahendra Singh Dhoni", "screen_name": "msdhoni", "location": "India", "description": "Member TEAM INDIA, Biker, Gamer, hindi retro aficionado, an absolute pet-lover and perennially hungry for chicken butter masala", "url": "https://t.co/0VBqy7KY6i", "entities": {"url": {"urls": [{"url": "https://t.co/0VBqy7KY6i", "expanded_url": "http://www.facebook.com/MSDhoni", "display_url": "facebook.com/MSDhoni", "indices": [0, 23]}]}, "description": {"urls": []}}, "protected": false, "followers_count": 7035595, "friends_count": 34, "listed_count": 12942, "created_at": "Thu Nov 26 07:42:07 +0000 2009", "favourites_count": 3, "utc_offset": 19800, "time_zone": "New Delhi", "geo_enabled": false, "verified": true, "statuses_count": 450, "lang": "en", "status": {"created_at": "Mon Apr 16 09:14:54 +0000 2018", "id": 985808741214941184, "id_str": "985808741214941184", "text": "When Ziva wanted to give a hug to papa during the match https://t.co/7f7qvsnqpG", "truncated": false, "entities": {"hashtags": [], "symbols": [], "user_mentions": [], "urls": [{"url": "https://t.co/7f7qvsnqpG", "expanded_url": "https://www.instagram.com/p/BhoDG_tHcei/", "display_url": "instagram.com/p/BhoDG_tHcei/", "indices": [56, 79]}]}, "source": "<a href=\"http://instagram.com\" rel=\"nofollow\">Instagram</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 6013, "favorite_count": 37198, "favorited": false, "retweeted": false, "possibly_sensitive": true, "lang": "en"}, "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "C0DEED", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/152707122/event_dp2.JPG", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/152707122/event_dp2.JPG", "profile_background_tile": false, "profile_image_url": "http://pbs.twimg.com/profile_images/790576698085416960/BkIjtFXR_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/790576698085416960/BkIjtFXR_normal.jpg", "profile_link_color": "0084B4", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "has_extended_profile": true, "default_profile": false, "default_profile_image": false, "following": true, "live_following": false, "follow_request_sent": false, "notifications": false, "muting": false, "blocking": false, "blocked_by": false, "translator_type": "none"}
# {"id": 56631494, "id_str": "56631494", "name": "Shahid Kapoor", "screen_name": "shahidkapoor", "location": "", "description": "Actor, Dreamer, Lover, Believer .", "url": "https://t.co/i0eyn5QK47", "entities": {"url": {"urls": [{"url": "https://t.co/i0eyn5QK47", "expanded_url": "http://facebook.com/shahidkapoor", "display_url": "facebook.com/shahidkapoor", "indices": [0, 23]}]}, "description": {"urls": []}}, "protected": false, "followers_count": 13230456, "friends_count": 102, "listed_count": 14169, "created_at": "Tue Jul 14 06:58:48 +0000 2009", "favourites_count": 615, "utc_offset": 19800, "time_zone": "Mumbai", "geo_enabled": false, "verified": true, "statuses_count": 6900, "lang": "en", "status": {"created_at": "Mon Apr 16 12:32:37 +0000 2018", "id": 985858500013297664, "id_str": "985858500013297664", "text": "Travel the way I do with @thecarriallco - It\u2019s two of my favorite things, cool and smart!\n\nCheck them out on\u2026 https://t.co/K7PzU4V1c3", "truncated": true, "entities": {"hashtags": [], "symbols": [], "user_mentions": [{"screen_name": "thecarriallco", "name": "TheCarriallCo", "id": 925341127049297920, "id_str": "925341127049297920", "indices": [25, 39]}], "urls": [{"url": "https://t.co/K7PzU4V1c3", "expanded_url": "https://twitter.com/i/web/status/985858500013297664", "display_url": "twitter.com/i/web/status/9\u2026", "indices": [110, 133]}]}, "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 252, "favorite_count": 2685, "favorited": false, "retweeted": false, "possibly_sensitive": false, "lang": "en"}, "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "C0DEED", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/140955190/0W9U0660__Large_.JPG", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/140955190/0W9U0660__Large_.JPG", "profile_background_tile": true, "profile_image_url": "http://pbs.twimg.com/profile_images/912295777585827842/0TxBGS9A_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/912295777585827842/0TxBGS9A_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/56631494/1515944890", "profile_link_color": "0084B4", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "has_extended_profile": false, "default_profile": false, "default_profile_image": false, "following": true, "live_following": false, "follow_request_sent": false, "notifications": false, "muting": false, "blocking": false, "blocked_by": false, "translator_type": "none"}
# ...
# {"id": 86254626, "id_str": "86254626", "name": "Preity zinta", "screen_name": "realpreityzinta", "location": "Catch me if you can....", "description": "Actor, Producer, Writer, Entrepreneur , Human Being and Cricket fan!", "url": "https://t.co/sRoWGMCPv4", "entities": {"url": {"urls": [{"url": "https://t.co/sRoWGMCPv4", "expanded_url": "https://www.facebook.com/officialpz", "display_url": "facebook.com/officialpz", "indices": [0, 23]}]}, "description": {"urls": []}}, "protected": false, "followers_count": 4275567, "friends_count": 93, "listed_count": 15673, "created_at": "Fri Oct 30 06:30:11 +0000 2009", "favourites_count": 782, "utc_offset": null, "time_zone": null, "geo_enabled": false, "verified": true, "statuses_count": 18658, "lang": "en", "status": {"created_at": "Thu Apr 19 10:35:35 +0000 2018", "id": 986916210079039488, "id_str": "986916210079039488", "text": "The fastest way to make ur dreams come true is to wake up &amp; get to work. #workhard #noshortcuts #dreambig\u2026 https://t.co/60qcK1q6gS", "truncated": true, "entities": {"hashtags": [{"text": "workhard", "indices": [77, 86]}, {"text": "noshortcuts", "indices": [87, 99]}, {"text": "dreambig", "indices": [100, 109]}], "symbols": [], "user_mentions": [], "urls": [{"url": "https://t.co/60qcK1q6gS", "expanded_url": "https://twitter.com/i/web/status/986916210079039488", "display_url": "twitter.com/i/web/status/9\u2026", "indices": [111, 134]}]}, "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 111, "favorite_count": 899, "favorited": false, "retweeted": false, "possibly_sensitive": true, "lang": "en"}, "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "131516", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/279547513/2rcwtw7.jpg", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/279547513/2rcwtw7.jpg", "profile_background_tile": false, "profile_image_url": "http://pbs.twimg.com/profile_images/917631983370461184/bXQjpkDe_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/917631983370461184/bXQjpkDe_normal.jpg", "profile_link_color": "009999", "profile_sidebar_border_color": "EEEEEE", "profile_sidebar_fill_color": "EFEFEF", "profile_text_color": "333333", "profile_use_background_image": true, "has_extended_profile": false, "default_profile": false, "default_profile_image": false, "following": true, "live_following": false, "follow_request_sent": false, "notifications": false, "muting": false, "blocking": false, "blocked_by": false, "translator_type": "none"}
# {"id": 19895282, "id_str": "19895282", "name": "A.R.Rahman", "screen_name": "arrahman", "location": "Chennai, India", "description": "Grammy and Academy Award winning musician                           (Reluctant Tweeter. Mostly Drowned in a Parallel Galaxy)", "url": "https://t.co/eHXO9MRi96", "entities": {"url": {"urls": [{"url": "https://t.co/eHXO9MRi96", "expanded_url": "http://www.arrahman.com", "display_url": "arrahman.com", "indices": [0, 23]}]}, "description": {"urls": []}}, "protected": false, "followers_count": 19856033, "friends_count": 1, "listed_count": 11258, "created_at": "Mon Feb 02 05:53:57 +0000 2009", "favourites_count": 66, "utc_offset": 19800, "time_zone": "Chennai", "geo_enabled": false, "verified": true, "statuses_count": 4438, "lang": "en", "status": {"created_at": "Thu Apr 19 16:39:57 +0000 2018", "id": 987007908914188288, "id_str": "987007908914188288", "text": "Vinyl Lovers, this is for you... https://t.co/Qvp1Qi4tjm", "truncated": false, "entities": {"hashtags": [], "symbols": [], "user_mentions": [], "urls": [], "media": [{"id": 987007905974005760, "id_str": "987007905974005760", "indices": [33, 56], "media_url": "http://pbs.twimg.com/media/DbKOdgoVMAAPIE7.jpg", "media_url_https": "https://pbs.twimg.com/media/DbKOdgoVMAAPIE7.jpg", "url": "https://t.co/Qvp1Qi4tjm", "display_url": "pic.twitter.com/Qvp1Qi4tjm", "expanded_url": "https://twitter.com/arrahman/status/987007908914188288/photo/1", "type": "photo", "sizes": {"thumb": {"w": 150, "h": 150, "resize": "crop"}, "medium": {"w": 819, "h": 1200, "resize": "fit"}, "small": {"w": 464, "h": 680, "resize": "fit"}, "large": {"w": 1398, "h": 2048, "resize": "fit"}}}]}, "extended_entities": {"media": [{"id": 987007905974005760, "id_str": "987007905974005760", "indices": [33, 56], "media_url": "http://pbs.twimg.com/media/DbKOdgoVMAAPIE7.jpg", "media_url_https": "https://pbs.twimg.com/media/DbKOdgoVMAAPIE7.jpg", "url": "https://t.co/Qvp1Qi4tjm", "display_url": "pic.twitter.com/Qvp1Qi4tjm", "expanded_url": "https://twitter.com/arrahman/status/987007908914188288/photo/1", "type": "photo", "sizes": {"thumb": {"w": 150, "h": 150, "resize": "crop"}, "medium": {"w": 819, "h": 1200, "resize": "fit"}, "small": {"w": 464, "h": 680, "resize": "fit"}, "large": {"w": 1398, "h": 2048, "resize": "fit"}}}]}, "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 180, "favorite_count": 1512, "favorited": false, "retweeted": false, "possibly_sensitive": false, "lang": "en"}, "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "C6E2EE", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/737604036/3179cc1733a2b605d117e3661d8439ad.jpeg", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/737604036/3179cc1733a2b605d117e3661d8439ad.jpeg", "profile_background_tile": false, "profile_image_url": "http://pbs.twimg.com/profile_images/597865661264596992/NnOqToId_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/597865661264596992/NnOqToId_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/19895282/1493060067", "profile_link_color": "1F98C7", "profile_sidebar_border_color": "FFFFFF", "profile_sidebar_fill_color": "DAECF4", "profile_text_color": "663B12", "profile_use_background_image": true, "has_extended_profile": false, "default_profile": false, "default_profile_image": false, "following": true, "live_following": false, "follow_request_sent": false, "notifications": false, "muting": false, "blocking": false, "blocked_by": false, "translator_type": "none"}
profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "has_extended_profile": false, "default_profile": true, "default_profile_image": false, "following": true, "live_following": false, "follow_request_sent": false, "notif ...
# {"id": 136720831, "id_str": "136720831", "name": "Niraj P", "screen_name": "Niraj_padhye", "location": "", "description": "", "url": null, "entities": {"description": {"urls": []}}, "protected": false, "followers_count": 103, "friends_count": 129, "listed_count": 1, "created_at": "Sat Apr 24 18:31:04 +0000 2010", "favourites_count": 32, "utc_offset": 14400, "time_zone": "Abu Dhabi", "geo_enabled": false, "verified": false, "statuses_count": 71, "lang": "en", "status": {"created_at": "Wed Sep 06 17:22:41 +0000 2017", "id": 905481389935656964, "id_str": "905481389935656964", "text": "RT @bhogleharsha: India started this series as favourites but to overwhelm the opposition 9-0 is quite staggering.", "truncated": false, "entities": {"hashtags": [], "symbols": [], "user_mentions": [{"screen_name": "bhogleharsha", "name": "Harsha Bhogle", "id": 78941611, "id_str": "78941611", "indices": [3, 16]}], "urls": []}, "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Lite</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "geo": null, "coordinates": null, "place": null, "contributors": null, "retweeted_status": {"created_at": "Wed Sep 06 17:21:44 +0000 2017", "id": 905481152026124288, "id_str": "905481152026124288", "text": "India started this series as favourites but to overwhelm the opposition 9-0 is quite staggering.", "truncated": false, "entities": {"hashtags": [], "symbols": [], "user_mentions": [], "urls": []}, "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 271, "favorite_count": 1486, "favorited": false, "retweeted": false, "lang": "en"}, "is_quote_status": false, "retweet_count": 271, "favorite_count": 0, "favorited": false, "retweeted": false, "lang": "en"}, "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "C0DEED", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_tile": false, "profile_image_url": "http://pbs.twimg.com/profile_images/3273917613/67cee45bef23dd848156432c698d66c7_normal.jpeg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/3273917613/67cee45bef23dd848156432c698d66c7_normal.jpeg", "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "has_extended_profile": false, "default_profile": true, "default_profile_image": false, "following": true, "live_following": false, "follow_request_sent": false, "notifications": false, "muting": false, "blocking": false, "blocked_by": false, "translator_type": "none"}

# %% [markdown]
# ##### for tweet in tweepy.Cursor(api.user_timeline).items():
#     process_or_store(tweet._json)

# %%
from tweepy import Stream
from tweepy.streaming import StreamListener
 
class MyListener(StreamListener):
 
    def on_data(self, data):
        try:
            with open('python.json', 'a') as f:
                f.write(data)
                return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True

twitter_stream = Stream(auth, MyListener())
twitter_stream.filter(track=['#python'])
# Out:
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1714             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1715         self._raise_ssl_error(self._ssl, result)
#    1716
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1520         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1521             raise WantReadError()
#    1522         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-1f38ea27aa1a> in <module>()
#      18
#      19 twitter_stream = Stream(auth, MyListener())
# ---> 20 twitter_stream.filter(track=['#python'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     448         self.session.params = {'delimited': 'length'}
#     449         self.host = 'stream.twitter.com'
# --> 450         self._start(async)
#     451
#     452     def sitestream(self, follow, stall_warnings=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, async)
#     362             self._thread.start()
#     363         else:
# --> 364             self._run()
#     365
#     366     def on_closed(self, resp):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     264                     self.snooze_time = self.snooze_time_step
#     265                     self.listener.on_connect()
# --> 266                     self._read_loop(resp)
#     267             except (Timeout, ssl.SSLError) as exc:
#     268                 # This is still necessary, as a SSLError can actually be
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     314             length = 0
#     315             while not resp.raw.closed:
# --> 316                 line = buf.read_line().strip()
#     317                 if not line:
#     318                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# C:\ProgramData\Anaconda3\lib\http\client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     290                 raise
#     291         except OpenSSL.SSL.WantReadError:
# --> 292             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     293             if not rd:
#     294                 raise timeout('The read operation timed out')
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\wait.py in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\wait.py in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\selectors.py in select(self, timeout)
#     318             ready = []
#     319             r, w, _ = _syscall_wrapper(self._select, True, self._readers,
# --> 320                                        self._writers, timeout)
#     321             r = set(r)
#     322             w = set(w)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\selectors.py in _syscall_wrapper(func, _, *args, **kwargs)
#      62         and recalculate their timeouts. """
#      63         try:
# ---> 64             return func(*args, **kwargs)
#      65         except (OSError, IOError, select.error) as e:
#      66             errcode = None
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\selectors.py in _select(self, r, w, timeout)
#     308         def _select(self, r, w, timeout=None):
#     309             """ Wrapper for select.select because timeout is a positional arg """
# --> 310             return select.select(r, w, [], timeout)
#     311
#     312         def select(self, timeout=None):
#
# KeyboardInterrupt:

# %%
with open('python.json', 'r') as f:
    line = f.readline() # read only the first tweet/line
    tweet = json.loads(line) # load it as Python dict
    print(json.dumps(tweet, indent=4)) # pretty-print
# Out:
# {
#     "created_at": "Fri Apr 20 00:38:23 +0000 2018",
#     "id": 987128308981731329,
#     "id_str": "987128308981731329",
#     "text": "RT @gravitygadz: Build your future with financial literacy, automation technology, data analytics and transparency.\n-&gt; https://t.co/5iiX8sY\u2026",
#     "source": "<a href=\"https://twitter.com/alevergara78\" rel=\"nofollow\">realtimeApp_reactjs</a>",
#     "truncated": false,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "user": {
#         "id": 104520454,
#         "id_str": "104520454",
#         "name": "alejandro vergara",
#         "screen_name": "alevergara78",
#         "location": "Santiago, Chile",
#         "url": "http://cl.linkedin.com/in/alevergara",
#         "description": "Any fool can write code that a computer can understand. Good programmers write code that humans can understand. Martin Fowler.\n#BigData  #machinelearning",
#         "translator_type": "none",
#         "protected": false,
#         "verified": false,
#         "followers_count": 15111,
#         "friends_count": 721,
#         "listed_count": 4035,
#         "favourites_count": 1381,
#         "statuses_count": 860599,
#         "created_at": "Wed Jan 13 15:46:14 +0000 2010",
#         "utc_offset": -10800,
#         "time_zone": "Santiago",
#         "geo_enabled": true,
#         "lang": "en",
#         "contributors_enabled": false,
#         "is_translator": false,
#         "profile_background_color": "000000",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_link_color": "02243B",
#         "profile_sidebar_border_color": "000000",
#         "profile_sidebar_fill_color": "000000",
#         "profile_text_color": "000000",
#         "profile_use_background_image": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/477167045772312577/3q1ssMVN_normal.jpeg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/477167045772312577/3q1ssMVN_normal.jpeg",
#         "default_profile": false,
#         "default_profile_image": false,
#         "following": null,
#         "follow_request_sent": null,
#         "notifications": null
#     },
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "retweeted_status": {
#         "created_at": "Fri Apr 20 00:37:45 +0000 2018",
#         "id": 987128150948659200,
#         "id_str": "987128150948659200",
#         "text": "Build your future with financial literacy, automation technology, data analytics and transparency.\n-&gt;\u2026 https://t.co/DPZqYP56wo",
#         "display_text_range": [
#             0,
#             140
#         ],
#         "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#         "truncated": true,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 472613504,
#             "id_str": "472613504",
#             "name": "follow back",
#             "screen_name": "gravitygadz",
#             "location": null,
#             "url": "https://twitter.com/gravitygadz",
#             "description": "just an average citizen #follow_Back\ud83d\ude00 #followforfollow #cryptocurrency #blockchain #bountyhunter",
#             "translator_type": "none",
#             "protected": false,
#             "verified": false,
#             "followers_count": 3214,
#             "friends_count": 3163,
#             "listed_count": 10,
#             "favourites_count": 3321,
#             "statuses_count": 6151,
#             "created_at": "Tue Jan 24 03:52:36 +0000 2012",
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "lang": "en",
#             "contributors_enabled": false,
#             "is_translator": false,
#             "profile_background_color": "000000",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_link_color": "1B95E0",
#             "profile_sidebar_border_color": "000000",
#             "profile_sidebar_fill_color": "000000",
#             "profile_text_color": "000000",
#             "profile_use_background_image": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/949119623391100930/oPlRNijp_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/949119623391100930/oPlRNijp_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/472613504/1508390449",
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": null,
#             "follow_request_sent": null,
#             "notifications": null
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "extended_tweet": {
#             "full_text": "Build your future with financial literacy, automation technology, data analytics and transparency.\n-&gt; https://t.co/5iiX8sYqh3\n@_Peculium\n#machinelearning #ai #neuralnetwork #sklearn #python #scikit #R #fintech #BigData #DataAnalytics #transparency #blockchain #savings #AIEVE https://t.co/Ozj5iDupgj",
#             "display_text_range": [
#                 0,
#                 278
#             ],
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "machinelearning",
#                         "indices": [
#                             140,
#                             156
#                         ]
#                     },
#                     {
#                         "text": "ai",
#                         "indices": [
#                             157,
#                             160
#                         ]
#                     },
#                     {
#                         "text": "neuralnetwork",
#                         "indices": [
#                             161,
#                             175
#                         ]
#                     },
#                     {
#                         "text": "sklearn",
#                         "indices": [
#                             176,
#                             184
#                         ]
#                     },
#                     {
#                         "text": "python",
#                         "indices": [
#                             185,
#                             192
#                         ]
#                     },
#                     {
#                         "text": "scikit",
#                         "indices": [
#                             193,
#                             200
#                         ]
#                     },
#                     {
#                         "text": "R",
#                         "indices": [
#                             201,
#                             203
#                         ]
#                     },
#                     {
#                         "text": "fintech",
#                         "indices": [
#                             204,
#                             212
#                         ]
#                     },
#                     {
#                         "text": "BigData",
#                         "indices": [
#                             213,
#                             221
#                         ]
#                     },
#                     {
#                         "text": "DataAnalytics",
#                         "indices": [
#                             222,
#                             236
#                         ]
#                     },
#                     {
#                         "text": "transparency",
#                         "indices": [
#                             237,
#                             250
#                         ]
#                     },
#                     {
#                         "text": "blockchain",
#                         "indices": [
#                             251,
#                             262
#                         ]
#                     },
#                     {
#                         "text": "savings",
#                         "indices": [
#                             263,
#                             271
#                         ]
#                     },
#                     {
#                         "text": "AIEVE",
#                         "indices": [
#                             272,
#                             278
#                         ]
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "url": "https://t.co/5iiX8sYqh3",
#                         "expanded_url": "https://product.aieve.io:8443/aieve",
#                         "display_url": "product.aieve.io:8443/aieve",
#                         "indices": [
#                             105,
#                             128
#                         ]
#                     }
#                 ],
#                 "user_mentions": [
#                     {
#                         "screen_name": "_Peculium",
#                         "name": "Peculium",
#                         "id": 898470396089036800,
#                         "id_str": "898470396089036800",
#                         "indices": [
#                             129,
#                             139
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "media": [
#                     {
#                         "id": 987127687087968256,
#                         "id_str": "987127687087968256",
#                         "indices": [
#                             279,
#                             302
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/DbL7ZsDU0AAVciu.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/DbL7ZsDU0AAVciu.jpg",
#                         "url": "https://t.co/Ozj5iDupgj",
#                         "display_url": "pic.twitter.com/Ozj5iDupgj",
#                         "expanded_url": "https://twitter.com/gravitygadz/status/987128150948659200/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 589,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 1220,
#                                 "h": 599,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 334,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 987127687087968256,
#                         "id_str": "987127687087968256",
#                         "indices": [
#                             279,
#                             302
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/DbL7ZsDU0AAVciu.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/DbL7ZsDU0AAVciu.jpg",
#                         "url": "https://t.co/Ozj5iDupgj",
#                         "display_url": "pic.twitter.com/Ozj5iDupgj",
#                         "expanded_url": "https://twitter.com/gravitygadz/status/987128150948659200/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 589,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 1220,
#                                 "h": 599,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 334,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             }
#         },
#         "quote_count": 0,
#         "reply_count": 0,
#         "retweet_count": 1,
#         "favorite_count": 0,
#         "entities": {
#             "hashtags": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/DPZqYP56wo",
#                     "expanded_url": "https://twitter.com/i/web/status/987128150948659200",
#                     "display_url": "twitter.com/i/web/status/9\u2026",
#                     "indices": [
#                         106,
#                         129
#                     ]
#                 }
#             ],
#             "user_mentions": [],
#             "symbols": []
#         },
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "filter_level": "low",
#         "lang": "en"
#     },
#     "is_quote_status": false,
#     "quote_count": 0,
#     "reply_count": 0,
#     "retweet_count": 0,
#     "favorite_count": 0,
#     "entities": {
#         "hashtags": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "screen_name": "gravitygadz",
#                 "name": "follow back",
#                 "id": 472613504,
#                 "id_str": "472613504",
#                 "indices": [
#                     3,
#                     15
#                 ]
#             }
#         ],
#         "symbols": []
#     },
#     "favorited": false,
#     "retweeted": false,
#     "filter_level": "low",
#     "lang": "en",
#     "timestamp_ms": "1524184703475"
# }

# %%
from nltk.tokenize import word_tokenize
 
tweet = 'RT @marcobonzanini: just an example! :D http://example.com #NLP'
print(word_tokenize(tweet))
# ['RT', '@', 'marcobonzanini', ':', 'just', 'an', 'example', '!', ':', 'D', 'http', ':', '//example.com', '#', 'NLP']
# Out:
# ['RT', '@', 'marcobonzanini', ':', 'just', 'an', 'example', '!', ':', 'D', 'http', ':', '//example.com', '#', 'NLP']

# %%
import re
 
emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\]/\\OpP] # Mouth
    )"""
 
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
    
tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)
 
def tokenize(s):
    return tokens_re.findall(s)
 
def preprocess(s, lowercase=False):
    tokens = tokenize(s)
    if lowercase:
        tokens = [token if emoticon_re.search(token) else token.lower() for token in tokens]
    return tokens
 
tweet = 'RT @marcobonzanini: just an example! :D http://example.com #NLP'
print(preprocess(tweet))
# ['RT', '@marcobonzanini', ':', 'just', 'an', 'example', '!', ':D', 'http://example.com', '#NLP']
# Out:
# ['RT', '@marcobonzanini', ':', 'just', 'an', 'example', '!', ':D', 'http://example.com', '#NLP']

# %%
with open('python.json', 'r') as f:
    for line in f:
        tweet = json.loads(line)
        tokens = preprocess(tweet['text'])
        #do_something_else(tokens)

# %%
import operator 
import json
from collections import Counter
 
fname = 'python.json'
with open(fname, 'r') as f:
    count_all = Counter()
    for line in f:
        tweet = json.loads(line)
        # Create a list with all the terms
        terms_all = [term for term in preprocess(tweet['text'])]
        # Update the counter
        count_all.update(terms_all)
    # Print the first 5 most frequent words
    print(count_all.most_common(5))
# Out:
# [(':', 17), (',', 14), ('…', 11), ('RT', 9), ('#Python', 9)]

# %%
from nltk.corpus import stopwords
import string
 
punctuation = list(string.punctuation)
stop = stopwords.words('english') + punctuation + ['rt', 'via']

# %%
terms_stop = [term for term in preprocess(tweet['text']) if term not in stop]

# %%
# Count terms only once, equivalent to Document Frequency
terms_single = set(terms_all)
# Count hashtags only
terms_hash = [term for term in preprocess(tweet['text']) 
              if term.startswith('#')]
# Count terms only (no hashtags, no mentions)
terms_only = [term for term in preprocess(tweet['text']) 
              if term not in stop and
              not term.startswith(('#', '@'))] 
              # mind the ((double brackets))
              # startswith() takes a tuple (not a list) if 
              # we pass a list of inputs

# %%
from nltk import bigrams 
 
terms_bigram = bigrams(terms_stop)

# %%
from collections import defaultdict
# remember to include the other import from the previous post
 
com = defaultdict(lambda : defaultdict(int))
 
with open('python.json', 'r') as f:
    for line in f: 
        tweet = json.loads(line)
        terms_only = [term for term in preprocess(tweet['text']) 
                      if term not in stop 
                      and not term.startswith(('#', '@'))]

        # Build co-occurrence matrix
        for i in range(len(terms_only)-1):            
            for j in range(i+1, len(terms_only)):
                w1, w2 = sorted([terms_only[i], terms_only[j]])                
                if w1 != w2:
                    com[w1][w2] += 1

# %%
com_max = []
# For each term, look for the most common co-occurrent terms
for t1 in com:
    t1_max_terms = sorted(com[t1].items(), key=operator.itemgetter(1), reverse=True)[:5]
    for t2, t2_count in t1_max_terms:
        com_max.append(((t1, t2), t2_count))
# Get the most frequent co-occurrences
terms_max = sorted(com_max, key=operator.itemgetter(1), reverse=True)
print(terms_max[:5])
# Out:
# [(('RT', '…'), 8), (('RT', 'data'), 2), (('data', '…'), 2), (('Learn', '…'), 2), (('R', 'RT'), 2)]

# %%
#search_word = sys.argv[1] # pass a term as a command-line argument
search_word = 'data'
count_search = Counter()
with open('python.json', 'r') as f:
    for line in f:
        tweet = json.loads(line)
        terms_only = [term for term in preprocess(tweet['text']) 
                      if term not in stop 
                      and not term.startswith(('#', '@'))]
        if search_word in terms_only:
            count_search.update(terms_only)
print("Co-occurrence for %s:" % search_word)
print(count_search.most_common(20))
# Out:
# Co-occurrence for data:
# [('RT', 2), ('data', 2), ('…', 2), ('Build', 1), ('future', 1), ('financial', 1), ('literacy', 1), ('automation', 1), ('technology', 1), ('analytics', 1), ('transparency', 1), ('gt', 1), ('https://t.co/5iiX8sY', 1), ('Anaconda', 1), ('complete', 1), ('open', 1), ('source', 1), ('science', 1), ('package', 1), ('community', 1)]

# %%
import vincent
 
with open(fname, 'r') as f:
    count_all = Counter()
    for line in f:
        tweet = json.loads(line)
        tokens = [term for term in preprocess(tweet['text']) if term not in stop and not term.startswith(('#', '@'))]
count_all.update(tokens)
word_freq = count_all.most_common(20)
labels, freq = zip(*word_freq)
data = {'data': freq, 'x': labels}
bar = vincent.Bar(data, iter_idx='x')
bar.to_json('term_freq.json')

# %%
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-9-42bfa9211702> in <module>()
#       1 i = 0
# ----> 2 for status in tweepy.Cursor(api.home_timeline, q="Facebook").items():
#       3     # Process a single status
#       4     print(str(i))
#       5     i+=1
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     195         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     196             # Reached end of current page, get the next page...
# --> 197             self.current_page = self.page_iterator.next()
#     198             self.page_index = -1
#     199         self.page_index += 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     106
#     107         if self.index >= len(self.results) - 1:
# --> 108             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     109
#     110             if hasattr(self.method, '__self__'):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     248             return method
#     249         else:
# --> 250             return method.execute()
#     251
#     252     # Set pagination mode
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     232                     raise RateLimitError(error_msg, resp)
#     233                 else:
# --> 234                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     235
#     236             # Parse the response payload
#
# TweepError: Twitter error response: status code = 429
